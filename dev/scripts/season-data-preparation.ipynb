# %%
import os
import pandas as pd
import numpy as np
import time

# %%
current_dir = os.getcwd()

# %%
os.chdir(os.path.join(os.getcwd(), "..", "..", "dev", "data"));

# %%
team_id_df = pd.read_csv("team_id_map.csv");

# %%
player_id_df = pd.read_csv("player_id_map.csv");

# %%
os.chdir(current_dir);

# %%
seasons = ["2019-20"]

# %%
teams_in_season = {
    2016: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "West Bromwich Albion", "Southampton",
            "Leicester City", "Sunderland", "Hull City", "Swansea City", "Stoke City",
            "Middlesbrough", "West Ham United", "Burnley"],
        "champion_ls": "Leicester City",
        "top5_ls": ["Leicester City", "Arsenal", "Tottenham Hotspur", "Manchester City", "Manchester United"],
        "bottom5_ls": ["Watford", "West Bromwich Albion", "Crystal Palace", "Bournemouth", "Sunderland"],
        "promoted_ts": ["Middlesbrough", "Hull City", "Burnley"]
    },
    2017: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "West Bromwich Albion", "Southampton",
            "Leicester City", "Newcastle United", "Brighton and Hove Albion", "Swansea City", "Stoke City",
            "Huddersfield Town", "West Ham United", "Burnley"],
        "champion_ls": "Chelsea",
        "top5_ls": ["Chelsea", "Tottenham Hotspur", "Manchester City", "Liverpool", "Arsenal"],
        "bottom5_ls": ["Stoke City", "Crystal Palace", "Swansea City", "Burnley", "Watford"],
        "promoted_ts": ["Newcastle United", "Brighton and Hove Albion", "Huddersfield Town"]
    },
    2018: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "Wolverhampton Wanderers", "Southampton",
            "Leicester City", "Newcastle United", "Brighton and Hove Albion", "Cardiff City", "Fulham",
            "Huddersfield Town", "West Ham United", "Burnley"],
        "champion_ls": "Manchester City",
        "top5_ls": ["Manchester City", "Manchester United", "Tottenham Hotspur", "Liverpool", "Chelsea"],
        "bottom5_ls": ["West Ham United", "Watford", "Brighton and Hove Albion", "Huddersfield Town", "Southampton"],
        "promoted_ts": ["Wolverhampton Wanderers", "Cardiff City", "Fulham"]
    },
    2019: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "Wolverhampton Wanderers", "Southampton",
            "Leicester City", "Newcastle United", "Brighton and Hove Albion", "Norwich City", "Aston Villa",
            "Sheffield United", "West Ham United", "Burnley"],
        "champion_ls": "Manchester City",
        "top5_ls": ["Manchester City", "Liverpool", "Chelsea", "Tottenham Hotspur", "Arsenal"],
        "bottom5_ls": ["Newcastle United", "Bournemouth", "Burnley", "Southampton", "Brighton and Hove Albion"],
        "promoted_ts": ["Norwich City", "Aston Villa", "Sheffield United"]
    }
}

# %%
# -1 means L
# 0 means D
# 1 means W
def getResult(row):
    if (row["team_h_score"] == row["team_a_score"]):
        return 0;
    elif (row["at_home"] == 1 and row["team_h_score"] < row["team_a_score"]):
        return -1;
    elif (row["at_home"] == 1 and row["team_h_score"] > row["team_a_score"]):
        return 1;
    elif (row["at_home"] == 0 and row["team_h_score"] < row["team_a_score"]):
        return 1;
    elif (row["at_home"] == 0 and row["team_h_score"] > row["team_a_score"]):
        return -1;

# %%
# main columns
cols = ["season", "GW", "at_home", "player_id", "opponent_id", "champion_ls", "top5_ls", "bottom5_ls", "promoted_ts",
        "influence", "creativity", "threat", "ict_index"];

# %%
# to remove columns after data augmented
to_remove_cols = ["minutes", "goals_scored", "goals_conceded", "assists", "clean_sheets", "own_goals", "yellow_cards", "red_cards", "penalties_saved", "penalties_missed",
       "saves", "bonus", "bps", "result"];

# %%
# reset column orders
reset_cols = ["season", "GW", "at_home", "player_id", "opponent_id", "champion_ls", "top5_ls", "bottom5_ls", 
              "promoted_ts", 'assists', 'assists_pgw', 'bonus', 'bonus_pgw', 'bps',
       'bps_pgw', 'clean_sheets', 'clean_sheets_pgw',
        'creativity', 'creativity_pgw', 'goals_conceded',
       'goals_conceded_pgw', 'goals_scored', 'goals_scored_pgw', 'ict_index',
       'ict_index_pgw', 'influence', 'influence_pgw', 'minutes', 'minutes_pgw',
       'own_goals', 'own_goals_pgw', 'penalties_missed', 'penalties_missed_pgw',
       'penalties_saved', 'penalties_saved_pgw', 'red_cards', 'red_cards_pgw', 'result_pgw', 'saves',
       'saves_pgw', 'threat',
       'threat_pgw','yellow_cards', 'yellow_cards_pgw', 'total_points_pgw', 'total_points']

# %%
# columns to fix - change the type of it to be int
cols_to_fix = ["GW", "at_home", "player_id", "opponent_id", "champion_ls", "top5_ls", "bottom5_ls", 
               "promoted_ts", "total_points"]

# %%
for season in seasons:
    print("Preparing data for season: {}".format(season));
    print('*' * 100);
    
    # set the target season as an int version: 2016-17 -> 2016
    target_season = int("".join(season.split("-")[:-1]));
    
    # get the list of teams in that season and sort them
    teams = teams_in_season[target_season]["teams"];
    teams.sort();
    
    # get the champions, top5, bottom5 and promoted teams for that season
    champion_ls = teams_in_season[target_season]["champion_ls"];
    top5_ls = teams_in_season[target_season]["top5_ls"];
    bottom5_ls = teams_in_season[target_season]["bottom5_ls"];
    promoted_ts = teams_in_season[target_season]["promoted_ts"];
    
    # change to the season data directory
    os.chdir(os.path.join(os.getcwd(), "..", "..", "data", season, "gws"));
    
    # read the merged dataframe
    df = pd.read_csv("merged_gw_data.csv");
    
    # change to the data directory in the dev folder
    os.chdir(current_dir);
    os.chdir(os.path.join(os.getcwd(), "..", "..", "dev", "data"));
    
    # set the season
    df["season"] = target_season;
    
    # set team from the list of teams that season
    print(">> Setting opponent team names ...");
    # %time df["team"] = df["opponent_team"].apply(lambda team: teams[team-1]);
    print("✓ Done.");
    
    # encode the teams into id
    print(">> Encoding opponent team names into team ids ...");
    # %time df["opponent_id"] = df["team"].apply(lambda team: team_id_df[team_id_df["team_name"] == team]["team_id"].iloc[0]);
    print("✓ Done.");
    
    # set column for is champions last season
    print(">> Creating column for champions last season ...");
    # %time df["champion_ls"] = df["team"].apply(lambda team: 1 if team == champion_ls else 0);
    print("✓ Done.");
    
    # set column for top 5 last season
    print(">> Creating column for top 5 last season ...");
    # %time df["top5_ls"] = df["team"].apply(lambda team: 1 if team in top5_ls else 0);
    print("✓ Done.");
    
    # set column for bottom 5 last season
    print(">> Creating column for bottom 5 last season ...");
    # %time df["bottom5_ls"] = df["team"].apply(lambda team: 1 if team in bottom5_ls else 0);
    print("✓ Done.");
    
    # set column for promoted teams this season
    print(">> Creating column for promoted teams this season ...");
    # %time df["promoted_ts"] = df["team"].apply(lambda team: 1 if team in promoted_ts else 0);
    print("✓ Done.");
    
    # drop the opponent team and team columns
    print(">> Dropping team and opponent_team columns ...");
    # %time df.drop(["team", "opponent_team"], axis=1, inplace=True);
    print("✓ Done.");
    
    # encode the players into id
    print(">> Encoding player names into player ids ...");
    # %time df["player_id"] = df["name"].apply(lambda player: player_id_df[player_id_df["player_name"] == player]["player_id"].iloc[0]);
    print("✓ Done.");
    
    # encode was_home into labels
    print(">> Encoding at home into boolean labels ...");
    # %time df["at_home"] = df["was_home"].apply(lambda at_home: 0 if not at_home else 1);
    print("✓ Done.");
    
    # encode the result into -1, 0, 1
    print(">> Creating a column for game result ...");
    # %time df["result"] = df.apply(lambda row: getResult(row), axis=1);
    print("✓ Done.");
    
    # drop the player name and was home columns
    print(">> Dropping player name and was home columns ...");
    # %time df.drop(["name", "was_home"], axis=1, inplace=True);
    print(">> Done.");
    
    # drop the id column
    if 'id' in df.columns:
        print(">> Dropping id columns ...");
        # %time df.drop(["id"], axis=1, inplace=True);
        print("✓ Done.");
        
    # set the target column
    target_col = ["total_points"];
    
    # set columns to be all the columns
    cols = cols + to_remove_cols + target_col;
    
    # create a subset dataframe with the new columns
    current_season = df[cols];
    
    # sort the subset dataframe
    current_season.sort_values(["GW"], inplace=True);
    current_season.reset_index(inplace=True, drop=True);
    
    # create target previous gameweek columns
    target_pgw = ["total_points", "ict_index", "influence", "creativity", "threat"];
    target_pgw = target_pgw + to_remove_cols;
    player_ids = np.unique(current_season["player_id"]);
    
    # create a new dataframe that will be augmented to
    new_df = pd.DataFrame(columns=list(current_season.columns));
    
    # loop through each unique player and augment the data
    print(">> Augmenting player data for each gameweek ...");
    print('-' * 50);
    for player_id in player_ids:
        now = time.time();
        df_ = current_season[current_season["player_id"] == player_id]
        df_.reset_index(inplace=True, drop=True)
        for index in range(len(df_)):
            instance = df_.iloc[index]
            gw = instance["GW"];
            for target in target_pgw:
                if (gw == 1 or index == 0):
                    df_.ix[index, "{}_pgw".format(target)] = 0
                else:
                    df_.ix[index, "{}_pgw".format(target)] = df_.iloc[index-1][target]
        new_df = new_df.append(df_)
        later = time.time();
        difference = int(later - now);
        print("Completed player id {} --- Time taken: {}s".format(player_id, difference));
    print("✓ Done.");
    print('-' * 50);
    
    # fix the indices
    new_df.reset_index(inplace=True, drop=True);
    
    # subset the reset columns
    new_df = new_df[reset_cols];
    
    # fix the reset columns
    for col in cols_to_fix:
        new_df[col] = new_df[col].astype(int)
    
    # save the dataframe
    filename = "{}-prepared-data.csv".format(target_season);
    new_df.to_csv(filename, index=False);
    
    print("Done preparing data for {}. File saved at: {}".format(season, os.path.join(os.getcwd(), filename)));
    print('*' * 100);
    print("\n");
    
    # switch back to the scripts directory
    os.chdir(current_dir);
# Out:
# Preparing data for season: 2019-20
# ****************************************************************************************************
# >> Setting opponent team names ...
# CPU times: user 1.92 ms, sys: 171 µs, total: 2.09 ms
# Wall time: 2.01 ms
# ✓ Done.
# >> Encoding opponent team names into team ids ...
# CPU times: user 1.52 s, sys: 24 ms, total: 1.54 s
# Wall time: 1.53 s
# ✓ Done.
# >> Creating column for champions last season ...
# CPU times: user 1.47 ms, sys: 69 µs, total: 1.54 ms
# Wall time: 1.5 ms
# ✓ Done.
# >> Creating column for top 5 last season ...
# CPU times: user 1.57 ms, sys: 39 µs, total: 1.61 ms
# Wall time: 1.58 ms
# ✓ Done.
# >> Creating column for bottom 5 last season ...
# CPU times: user 1.63 ms, sys: 61 µs, total: 1.69 ms
# Wall time: 1.67 ms
# ✓ Done.
# >> Creating column for promoted teams this season ...
# CPU times: user 1.57 ms, sys: 74 µs, total: 1.65 ms
# Wall time: 1.62 ms
# ✓ Done.
# >> Dropping team and opponent_team columns ...
# CPU times: user 4.42 ms, sys: 1.3 ms, total: 5.72 ms
# Wall time: 4.71 ms
# ✓ Done.
# >> Encoding player names into player ids ...
# CPU times: user 1.69 s, sys: 31.3 ms, total: 1.72 s
# Wall time: 1.72 s
# ✓ Done.
# >> Encoding at home into boolean labels ...
# CPU times: user 1.54 ms, sys: 56 µs, total: 1.59 ms
# Wall time: 1.53 ms
# ✓ Done.
# >> Creating a column for game result ...
# CPU times: user 128 ms, sys: 1.91 ms, total: 130 ms
# Wall time: 135 ms
# ✓ Done.
# >> Dropping player name and was home columns ...
# CPU times: user 1.6 ms, sys: 223 µs, total: 1.82 ms
# Wall time: 1.67 ms
# >> Done.
# >> Augmenting player data for each gameweek ...
# --------------------------------------------------
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:125: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:127: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:6701: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Completed player id 1 --- Time taken: 2s
# Completed player id 2 --- Time taken: 2s
# Completed player id 3 --- Time taken: 2s
# Completed player id 5 --- Time taken: 2s
# Completed player id 6 --- Time taken: 2s
# Completed player id 12 --- Time taken: 2s
# Completed player id 15 --- Time taken: 2s
# Completed player id 17 --- Time taken: 2s
# Completed player id 18 --- Time taken: 2s
# Completed player id 21 --- Time taken: 2s
# Completed player id 22 --- Time taken: 2s
# Completed player id 26 --- Time taken: 2s
# Completed player id 33 --- Time taken: 2s
# Completed player id 34 --- Time taken: 2s
# Completed player id 35 --- Time taken: 2s
# Completed player id 40 --- Time taken: 2s
# Completed player id 47 --- Time taken: 2s
# Completed player id 49 --- Time taken: 2s
# Completed player id 51 --- Time taken: 2s
# Completed player id 52 --- Time taken: 2s
# Completed player id 53 --- Time taken: 2s
# Completed player id 55 --- Time taken: 2s
# Completed player id 56 --- Time taken: 2s
# Completed player id 57 --- Time taken: 2s
# Completed player id 59 --- Time taken: 2s
# Completed player id 60 --- Time taken: 2s
# Completed player id 61 --- Time taken: 2s
# Completed player id 65 --- Time taken: 2s
# Completed player id 66 --- Time taken: 2s
# Completed player id 67 --- Time taken: 2s
# Completed player id 69 --- Time taken: 2s
# Completed player id 71 --- Time taken: 2s
# Completed player id 72 --- Time taken: 2s
# Completed player id 73 --- Time taken: 2s
# Completed player id 78 --- Time taken: 2s
# Completed player id 81 --- Time taken: 2s
# Completed player id 82 --- Time taken: 2s
# Completed player id 83 --- Time taken: 2s
# Completed player id 86 --- Time taken: 2s
# Completed player id 91 --- Time taken: 2s
# Completed player id 108 --- Time taken: 2s
# Completed player id 109 --- Time taken: 2s
# Completed player id 113 --- Time taken: 2s
# Completed player id 118 --- Time taken: 2s
# Completed player id 119 --- Time taken: 2s
# Completed player id 121 --- Time taken: 2s
# Completed player id 124 --- Time taken: 2s
# Completed player id 125 --- Time taken: 2s
# Completed player id 126 --- Time taken: 2s
# Completed player id 127 --- Time taken: 2s
# Completed player id 128 --- Time taken: 2s
# Completed player id 131 --- Time taken: 2s
# Completed player id 136 --- Time taken: 2s
# Completed player id 138 --- Time taken: 2s
# Completed player id 139 --- Time taken: 2s
# Completed player id 145 --- Time taken: 2s
# Completed player id 146 --- Time taken: 2s
# Completed player id 151 --- Time taken: 2s
# Completed player id 153 --- Time taken: 2s
# Completed player id 156 --- Time taken: 2s
# Completed player id 157 --- Time taken: 2s
# Completed player id 161 --- Time taken: 2s
# Completed player id 162 --- Time taken: 2s
# Completed player id 164 --- Time taken: 2s
# Completed player id 168 --- Time taken: 2s
# Completed player id 170 --- Time taken: 2s
# Completed player id 175 --- Time taken: 2s
# Completed player id 176 --- Time taken: 2s
# Completed player id 177 --- Time taken: 2s
# Completed player id 179 --- Time taken: 2s
# Completed player id 180 --- Time taken: 2s
# Completed player id 181 --- Time taken: 2s
# Completed player id 191 --- Time taken: 2s
# Completed player id 192 --- Time taken: 2s
# Completed player id 193 --- Time taken: 2s
# Completed player id 194 --- Time taken: 2s
# Completed player id 202 --- Time taken: 2s
# Completed player id 210 --- Time taken: 2s
# Completed player id 211 --- Time taken: 2s
# Completed player id 212 --- Time taken: 2s
# Completed player id 213 --- Time taken: 2s
# Completed player id 215 --- Time taken: 2s
# Completed player id 219 --- Time taken: 2s
# Completed player id 222 --- Time taken: 2s
# Completed player id 225 --- Time taken: 2s
# Completed player id 231 --- Time taken: 2s
# Completed player id 234 --- Time taken: 2s
# Completed player id 237 --- Time taken: 2s
# Completed player id 244 --- Time taken: 2s
# Completed player id 245 --- Time taken: 2s
# Completed player id 246 --- Time taken: 2s
# Completed player id 253 --- Time taken: 2s
# Completed player id 258 --- Time taken: 2s
# Completed player id 264 --- Time taken: 2s
# Completed player id 266 --- Time taken: 2s
# Completed player id 267 --- Time taken: 2s
# Completed player id 268 --- Time taken: 2s
# Completed player id 269 --- Time taken: 2s
# Completed player id 270 --- Time taken: 2s
# Completed player id 273 --- Time taken: 2s
# Completed player id 275 --- Time taken: 2s
# Completed player id 277 --- Time taken: 2s
# Completed player id 279 --- Time taken: 2s
# Completed player id 283 --- Time taken: 2s
# Completed player id 286 --- Time taken: 2s
# Completed player id 287 --- Time taken: 2s
# Completed player id 291 --- Time taken: 2s
# Completed player id 294 --- Time taken: 2s
# Completed player id 295 --- Time taken: 2s
# Completed player id 297 --- Time taken: 2s
# Completed player id 299 --- Time taken: 2s
# Completed player id 300 --- Time taken: 2s
# Completed player id 301 --- Time taken: 2s
# Completed player id 304 --- Time taken: 2s
# Completed player id 306 --- Time taken: 2s
# Completed player id 310 --- Time taken: 2s
# Completed player id 312 --- Time taken: 2s
# Completed player id 313 --- Time taken: 2s
# Completed player id 316 --- Time taken: 2s
# Completed player id 320 --- Time taken: 2s
# Completed player id 323 --- Time taken: 2s
# Completed player id 329 --- Time taken: 2s
# Completed player id 332 --- Time taken: 1s
# Completed player id 334 --- Time taken: 1s
# Completed player id 337 --- Time taken: 1s
# Completed player id 348 --- Time taken: 2s
# Completed player id 349 --- Time taken: 2s
# Completed player id 350 --- Time taken: 2s
# Completed player id 351 --- Time taken: 2s
# Completed player id 354 --- Time taken: 2s
# Completed player id 358 --- Time taken: 2s
# Completed player id 360 --- Time taken: 2s
# Completed player id 367 --- Time taken: 2s
# Completed player id 370 --- Time taken: 2s
# Completed player id 373 --- Time taken: 2s
# Completed player id 378 --- Time taken: 2s
# Completed player id 382 --- Time taken: 2s
# Completed player id 383 --- Time taken: 2s
# Completed player id 385 --- Time taken: 2s
# Completed player id 386 --- Time taken: 2s
# Completed player id 392 --- Time taken: 2s
# Completed player id 394 --- Time taken: 2s
# Completed player id 396 --- Time taken: 2s
# Completed player id 398 --- Time taken: 2s
# Completed player id 401 --- Time taken: 2s
# Completed player id 402 --- Time taken: 2s
# Completed player id 407 --- Time taken: 2s
# Completed player id 408 --- Time taken: 2s
# Completed player id 416 --- Time taken: 2s
# Completed player id 418 --- Time taken: 2s
# Completed player id 419 --- Time taken: 2s
# Completed player id 421 --- Time taken: 2s
# Completed player id 423 --- Time taken: 2s
# Completed player id 425 --- Time taken: 2s
# Completed player id 428 --- Time taken: 2s
# Completed player id 432 --- Time taken: 2s
# Completed player id 433 --- Time taken: 2s
# Completed player id 439 --- Time taken: 2s
# Completed player id 440 --- Time taken: 2s
# Completed player id 442 --- Time taken: 2s
# Completed player id 445 --- Time taken: 2s
# Completed player id 446 --- Time taken: 2s
# Completed player id 451 --- Time taken: 2s
# Completed player id 455 --- Time taken: 2s
# Completed player id 456 --- Time taken: 2s
# Completed player id 463 --- Time taken: 2s
# Completed player id 464 --- Time taken: 2s
# Completed player id 466 --- Time taken: 2s
# Completed player id 472 --- Time taken: 2s
# Completed player id 474 --- Time taken: 2s
# Completed player id 478 --- Time taken: 2s
# Completed player id 483 --- Time taken: 2s
# Completed player id 485 --- Time taken: 2s
# Completed player id 491 --- Time taken: 2s
# Completed player id 493 --- Time taken: 2s
# Completed player id 498 --- Time taken: 2s
# Completed player id 500 --- Time taken: 2s
# Completed player id 503 --- Time taken: 2s
# Completed player id 504 --- Time taken: 2s
# Completed player id 505 --- Time taken: 2s
# Completed player id 508 --- Time taken: 2s
# Completed player id 509 --- Time taken: 2s
# Completed player id 511 --- Time taken: 2s
# Completed player id 512 --- Time taken: 2s
# Completed player id 513 --- Time taken: 1s
# Completed player id 514 --- Time taken: 2s
# Completed player id 520 --- Time taken: 2s
# Completed player id 521 --- Time taken: 2s
# Completed player id 522 --- Time taken: 2s
# Completed player id 527 --- Time taken: 2s
# Completed player id 532 --- Time taken: 2s
# Completed player id 537 --- Time taken: 2s
# Completed player id 539 --- Time taken: 2s
# Completed player id 541 --- Time taken: 2s
# Completed player id 543 --- Time taken: 2s
# Completed player id 544 --- Time taken: 2s
# Completed player id 548 --- Time taken: 2s
# Completed player id 549 --- Time taken: 2s
# Completed player id 550 --- Time taken: 2s
# Completed player id 553 --- Time taken: 2s
# Completed player id 555 --- Time taken: 2s
# Completed player id 563 --- Time taken: 2s
# Completed player id 566 --- Time taken: 2s
# Completed player id 567 --- Time taken: 2s
# Completed player id 568 --- Time taken: 2s
# Completed player id 569 --- Time taken: 2s
# Completed player id 571 --- Time taken: 2s
# Completed player id 572 --- Time taken: 2s
# Completed player id 573 --- Time taken: 2s
# Completed player id 574 --- Time taken: 2s
# Completed player id 576 --- Time taken: 2s
# Completed player id 578 --- Time taken: 2s
# Completed player id 581 --- Time taken: 2s
# Completed player id 582 --- Time taken: 2s
# Completed player id 585 --- Time taken: 2s
# Completed player id 588 --- Time taken: 2s
# Completed player id 592 --- Time taken: 2s
# Completed player id 598 --- Time taken: 2s
# Completed player id 599 --- Time taken: 2s
# Completed player id 600 --- Time taken: 2s
# Completed player id 602 --- Time taken: 2s
# Completed player id 604 --- Time taken: 2s
# Completed player id 605 --- Time taken: 2s
# Completed player id 606 --- Time taken: 2s
# Completed player id 611 --- Time taken: 2s
# Completed player id 612 --- Time taken: 2s
# Completed player id 613 --- Time taken: 2s
# Completed player id 615 --- Time taken: 2s
# Completed player id 621 --- Time taken: 2s
# Completed player id 625 --- Time taken: 2s
# Completed player id 630 --- Time taken: 2s
# Completed player id 634 --- Time taken: 2s
# Completed player id 640 --- Time taken: 2s
# Completed player id 643 --- Time taken: 2s
# Completed player id 644 --- Time taken: 2s
# Completed player id 645 --- Time taken: 2s
# Completed player id 648 --- Time taken: 2s
# Completed player id 649 --- Time taken: 2s
# Completed player id 651 --- Time taken: 2s
# Completed player id 655 --- Time taken: 2s
# Completed player id 657 --- Time taken: 2s
# Completed player id 659 --- Time taken: 2s
# Completed player id 663 --- Time taken: 2s
# Completed player id 666 --- Time taken: 2s
# Completed player id 667 --- Time taken: 2s
# Completed player id 669 --- Time taken: 2s
# Completed player id 671 --- Time taken: 2s
# Completed player id 672 --- Time taken: 2s
# Completed player id 673 --- Time taken: 2s
# Completed player id 674 --- Time taken: 2s
# Completed player id 684 --- Time taken: 2s
# Completed player id 692 --- Time taken: 2s
# Completed player id 696 --- Time taken: 2s
# Completed player id 698 --- Time taken: 2s
# Completed player id 700 --- Time taken: 2s
# Completed player id 701 --- Time taken: 2s
# Completed player id 702 --- Time taken: 2s
# Completed player id 703 --- Time taken: 2s
# Completed player id 705 --- Time taken: 2s
# Completed player id 706 --- Time taken: 2s
# Completed player id 707 --- Time taken: 2s
# Completed player id 711 --- Time taken: 2s
# Completed player id 712 --- Time taken: 2s
# Completed player id 714 --- Time taken: 2s
# Completed player id 717 --- Time taken: 2s
# Completed player id 718 --- Time taken: 2s
# Completed player id 720 --- Time taken: 2s
# Completed player id 726 --- Time taken: 2s
# Completed player id 728 --- Time taken: 2s
# Completed player id 729 --- Time taken: 2s
# Completed player id 732 --- Time taken: 2s
# Completed player id 733 --- Time taken: 2s
# Completed player id 735 --- Time taken: 2s
# Completed player id 742 --- Time taken: 2s
# Completed player id 743 --- Time taken: 2s
# Completed player id 745 --- Time taken: 2s
# Completed player id 747 --- Time taken: 2s
# Completed player id 751 --- Time taken: 2s
# Completed player id 753 --- Time taken: 2s
# Completed player id 755 --- Time taken: 2s
# Completed player id 757 --- Time taken: 2s
# Completed player id 759 --- Time taken: 2s
# Completed player id 761 --- Time taken: 2s
# Completed player id 762 --- Time taken: 2s
# Completed player id 763 --- Time taken: 2s
# Completed player id 766 --- Time taken: 2s
# Completed player id 769 --- Time taken: 2s
# Completed player id 771 --- Time taken: 2s
# Completed player id 773 --- Time taken: 2s
# Completed player id 775 --- Time taken: 2s
# Completed player id 776 --- Time taken: 2s
# Completed player id 777 --- Time taken: 0s
# Completed player id 778 --- Time taken: 2s
# Completed player id 781 --- Time taken: 2s
# Completed player id 784 --- Time taken: 2s
# Completed player id 794 --- Time taken: 2s
# Completed player id 796 --- Time taken: 2s
# Completed player id 799 --- Time taken: 2s
# Completed player id 801 --- Time taken: 2s
# Completed player id 804 --- Time taken: 2s
# Completed player id 805 --- Time taken: 2s
# Completed player id 806 --- Time taken: 2s
# Completed player id 809 --- Time taken: 2s
# Completed player id 815 --- Time taken: 2s
# Completed player id 820 --- Time taken: 2s
# Completed player id 822 --- Time taken: 2s
# Completed player id 825 --- Time taken: 2s
# Completed player id 829 --- Time taken: 2s
# Completed player id 832 --- Time taken: 2s
# Completed player id 835 --- Time taken: 2s
# Completed player id 836 --- Time taken: 2s
# Completed player id 839 --- Time taken: 2s
# Completed player id 841 --- Time taken: 2s
# Completed player id 850 --- Time taken: 2s
# Completed player id 853 --- Time taken: 2s
# Completed player id 855 --- Time taken: 2s
# Completed player id 856 --- Time taken: 2s
# Completed player id 857 --- Time taken: 2s
# Completed player id 858 --- Time taken: 2s
# Completed player id 859 --- Time taken: 2s
# Completed player id 862 --- Time taken: 2s
# Completed player id 864 --- Time taken: 2s
# Completed player id 867 --- Time taken: 2s
# Completed player id 874 --- Time taken: 2s
# Completed player id 876 --- Time taken: 2s
# Completed player id 877 --- Time taken: 2s
# Completed player id 879 --- Time taken: 2s
# Completed player id 882 --- Time taken: 2s
# Completed player id 886 --- Time taken: 2s
# Completed player id 894 --- Time taken: 2s
# Completed player id 895 --- Time taken: 2s
# Completed player id 896 --- Time taken: 2s
# Completed player id 903 --- Time taken: 2s
# Completed player id 907 --- Time taken: 2s
# Completed player id 909 --- Time taken: 2s
# Completed player id 910 --- Time taken: 2s
# Completed player id 911 --- Time taken: 2s
# Completed player id 912 --- Time taken: 2s
# Completed player id 924 --- Time taken: 2s
# Completed player id 925 --- Time taken: 2s
# Completed player id 926 --- Time taken: 2s
# Completed player id 932 --- Time taken: 0s
# Completed player id 936 --- Time taken: 2s
# Completed player id 938 --- Time taken: 2s
# Completed player id 939 --- Time taken: 2s
# Completed player id 940 --- Time taken: 2s
# Completed player id 943 --- Time taken: 2s
# Completed player id 946 --- Time taken: 2s
# Completed player id 947 --- Time taken: 2s
# Completed player id 952 --- Time taken: 2s
# Completed player id 953 --- Time taken: 2s
# Completed player id 955 --- Time taken: 2s
# Completed player id 957 --- Time taken: 2s
# Completed player id 958 --- Time taken: 2s
# Completed player id 959 --- Time taken: 2s
# Completed player id 961 --- Time taken: 2s
# Completed player id 963 --- Time taken: 2s
# Completed player id 965 --- Time taken: 2s
# Completed player id 966 --- Time taken: 2s
# Completed player id 973 --- Time taken: 2s
# Completed player id 976 --- Time taken: 2s
# Completed player id 977 --- Time taken: 2s
# Completed player id 978 --- Time taken: 2s
# Completed player id 979 --- Time taken: 2s
# Completed player id 980 --- Time taken: 2s
# Completed player id 982 --- Time taken: 2s
# Completed player id 985 --- Time taken: 2s
# Completed player id 991 --- Time taken: 2s
# Completed player id 992 --- Time taken: 2s
# Completed player id 993 --- Time taken: 2s
# Completed player id 997 --- Time taken: 2s
# Completed player id 998 --- Time taken: 2s
# Completed player id 1002 --- Time taken: 2s
# Completed player id 1004 --- Time taken: 2s
# Completed player id 1006 --- Time taken: 2s
# Completed player id 1009 --- Time taken: 2s
# Completed player id 1010 --- Time taken: 2s
# Completed player id 1013 --- Time taken: 2s
# Completed player id 1017 --- Time taken: 2s
# Completed player id 1019 --- Time taken: 2s
# Completed player id 1021 --- Time taken: 2s
# Completed player id 1022 --- Time taken: 2s
# Completed player id 1024 --- Time taken: 1s
# Completed player id 1025 --- Time taken: 1s
# Completed player id 1026 --- Time taken: 2s
# Completed player id 1027 --- Time taken: 2s
# Completed player id 1028 --- Time taken: 2s
# Completed player id 1029 --- Time taken: 2s
# Completed player id 1032 --- Time taken: 2s
# Completed player id 1033 --- Time taken: 2s
# Completed player id 1036 --- Time taken: 2s
# Completed player id 1037 --- Time taken: 2s
# Completed player id 1038 --- Time taken: 2s
# Completed player id 1039 --- Time taken: 2s
# Completed player id 1045 --- Time taken: 2s
# Completed player id 1048 --- Time taken: 2s
# Completed player id 1049 --- Time taken: 2s
# Completed player id 1051 --- Time taken: 2s
# Completed player id 1053 --- Time taken: 2s
# Completed player id 1055 --- Time taken: 2s
# Completed player id 1057 --- Time taken: 2s
# Completed player id 1060 --- Time taken: 2s
# Completed player id 1061 --- Time taken: 2s
# Completed player id 1063 --- Time taken: 2s
# Completed player id 1064 --- Time taken: 2s
# Completed player id 1065 --- Time taken: 2s
# Completed player id 1066 --- Time taken: 2s
# Completed player id 1068 --- Time taken: 2s
# Completed player id 1071 --- Time taken: 2s
# Completed player id 1075 --- Time taken: 2s
# Completed player id 1076 --- Time taken: 2s
# Completed player id 1080 --- Time taken: 2s
# Completed player id 1081 --- Time taken: 2s
# Completed player id 1083 --- Time taken: 2s
# Completed player id 1084 --- Time taken: 2s
# Completed player id 1085 --- Time taken: 2s
# Completed player id 1086 --- Time taken: 2s
# Completed player id 1087 --- Time taken: 2s
# Completed player id 1088 --- Time taken: 2s
# Completed player id 1089 --- Time taken: 2s
# Completed player id 1090 --- Time taken: 2s
# Completed player id 1093 --- Time taken: 2s
# Completed player id 1094 --- Time taken: 1s
# Completed player id 1095 --- Time taken: 0s
# Completed player id 1096 --- Time taken: 2s
# Completed player id 1097 --- Time taken: 2s
# Completed player id 1098 --- Time taken: 2s
# Completed player id 1099 --- Time taken: 2s
# Completed player id 1100 --- Time taken: 2s
# Completed player id 1101 --- Time taken: 2s
# Completed player id 1102 --- Time taken: 2s
# Completed player id 1103 --- Time taken: 2s
# Completed player id 1104 --- Time taken: 2s
# Completed player id 1105 --- Time taken: 2s
# Completed player id 1106 --- Time taken: 2s
# Completed player id 1107 --- Time taken: 2s
# Completed player id 1108 --- Time taken: 0s
# Completed player id 1109 --- Time taken: 2s
# Completed player id 1110 --- Time taken: 2s
# Completed player id 1111 --- Time taken: 2s
# Completed player id 1112 --- Time taken: 2s
# Completed player id 1113 --- Time taken: 2s
# Completed player id 1114 --- Time taken: 2s
# Completed player id 1115 --- Time taken: 2s
# Completed player id 1116 --- Time taken: 2s
# Completed player id 1117 --- Time taken: 2s
# Completed player id 1118 --- Time taken: 2s
# Completed player id 1119 --- Time taken: 2s
# Completed player id 1120 --- Time taken: 1s
# Completed player id 1121 --- Time taken: 2s
# Completed player id 1122 --- Time taken: 2s
# Completed player id 1123 --- Time taken: 2s
# Completed player id 1124 --- Time taken: 2s
# Completed player id 1125 --- Time taken: 0s
# Completed player id 1126 --- Time taken: 2s
# Completed player id 1127 --- Time taken: 2s
# Completed player id 1128 --- Time taken: 2s
# Completed player id 1129 --- Time taken: 2s
# Completed player id 1130 --- Time taken: 2s
# Completed player id 1131 --- Time taken: 2s
# Completed player id 1132 --- Time taken: 2s
# Completed player id 1133 --- Time taken: 2s
# Completed player id 1134 --- Time taken: 2s
# Completed player id 1135 --- Time taken: 2s
# Completed player id 1136 --- Time taken: 2s
# Completed player id 1137 --- Time taken: 2s
# Completed player id 1138 --- Time taken: 2s
# Completed player id 1139 --- Time taken: 2s
# Completed player id 1140 --- Time taken: 2s
# Completed player id 1141 --- Time taken: 2s
# Completed player id 1142 --- Time taken: 2s
# Completed player id 1143 --- Time taken: 2s
# Completed player id 1144 --- Time taken: 2s
# Completed player id 1145 --- Time taken: 2s
# Completed player id 1146 --- Time taken: 2s
# Completed player id 1147 --- Time taken: 2s
# Completed player id 1148 --- Time taken: 2s
# Completed player id 1149 --- Time taken: 2s
# Completed player id 1150 --- Time taken: 2s
# Completed player id 1151 --- Time taken: 2s
# Completed player id 1152 --- Time taken: 2s
# Completed player id 1153 --- Time taken: 2s
# Completed player id 1154 --- Time taken: 2s
# Completed player id 1155 --- Time taken: 2s
# Completed player id 1156 --- Time taken: 2s
# Completed player id 1157 --- Time taken: 2s
# Completed player id 1158 --- Time taken: 2s
# Completed player id 1159 --- Time taken: 2s
# Completed player id 1160 --- Time taken: 2s
# Completed player id 1161 --- Time taken: 2s
# Completed player id 1162 --- Time taken: 2s
# Completed player id 1163 --- Time taken: 2s
# Completed player id 1164 --- Time taken: 2s
# Completed player id 1165 --- Time taken: 2s
# Completed player id 1166 --- Time taken: 2s
# Completed player id 1167 --- Time taken: 2s
# Completed player id 1168 --- Time taken: 2s
# Completed player id 1169 --- Time taken: 2s
# Completed player id 1170 --- Time taken: 2s
# Completed player id 1171 --- Time taken: 2s
# Completed player id 1172 --- Time taken: 2s
# Completed player id 1173 --- Time taken: 2s
# Completed player id 1174 --- Time taken: 2s
# Completed player id 1175 --- Time taken: 2s
# Completed player id 1176 --- Time taken: 2s
# Completed player id 1177 --- Time taken: 0s
# Completed player id 1178 --- Time taken: 2s
# Completed player id 1179 --- Time taken: 2s
# Completed player id 1180 --- Time taken: 2s
# Completed player id 1181 --- Time taken: 2s
# Completed player id 1182 --- Time taken: 2s
# Completed player id 1183 --- Time taken: 2s
# Completed player id 1184 --- Time taken: 2s
# Completed player id 1185 --- Time taken: 2s
# Completed player id 1186 --- Time taken: 2s
# Completed player id 1187 --- Time taken: 2s
# Completed player id 1188 --- Time taken: 2s
# Completed player id 1189 --- Time taken: 2s
# Completed player id 1190 --- Time taken: 2s
# Completed player id 1191 --- Time taken: 2s
# Completed player id 1192 --- Time taken: 2s
# Completed player id 1193 --- Time taken: 2s
# Completed player id 1194 --- Time taken: 2s
# Completed player id 1195 --- Time taken: 2s
# Completed player id 1196 --- Time taken: 2s
# Completed player id 1197 --- Time taken: 2s
# Completed player id 1198 --- Time taken: 2s
# Completed player id 1199 --- Time taken: 2s
# Completed player id 1200 --- Time taken: 0s
# Completed player id 1201 --- Time taken: 2s
# Completed player id 1202 --- Time taken: 2s
# Completed player id 1203 --- Time taken: 2s
# Completed player id 1204 --- Time taken: 2s
# Completed player id 1205 --- Time taken: 2s
# Completed player id 1206 --- Time taken: 2s
# Completed player id 1207 --- Time taken: 2s
# Completed player id 1208 --- Time taken: 0s
# Completed player id 1209 --- Time taken: 2s
# Completed player id 1210 --- Time taken: 2s
# ✓ Done.
# --------------------------------------------------
# Done preparing data for 2019-20. File saved at: /Users/sakib@ibm.com/workspace/other/projects/Fantasy-Premier-League/dev/data/2019-prepared-data.csv
# ****************************************************************************************************
