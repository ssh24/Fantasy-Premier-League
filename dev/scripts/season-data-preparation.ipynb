# %%
import os
import pandas as pd
import numpy as np
import time

# %%
current_dir = os.getcwd()

# %%
os.chdir(os.path.join(os.getcwd(), "..", "..", "dev", "data"));

# %%
team_id_df = pd.read_csv("team_id_map.csv");

# %%
player_id_df = pd.read_csv("player_id_map.csv");

# %%
os.chdir(current_dir);

# %%
seasons = ["2016-17", "2017-18", "2018-19"];
# "2019-20"

# %%
teams_in_season = {
    2016: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "West Bromwich Albion", "Southampton",
            "Leicester City", "Sunderland", "Hull City", "Swansea City", "Stoke City",
            "Middlesbrough", "West Ham United", "Burnley"],
        "champion_ls": "Leicester City",
        "top5_ls": ["Leicester City", "Arsenal", "Tottenham Hotspur", "Manchester City", "Manchester United"],
        "bottom5_ls": ["Watford", "West Bromwich Albion", "Crystal Palace", "Bournemouth", "Sunderland"],
        "promoted_ts": ["Middlesbrough", "Hull City", "Burnley"]
    },
    2017: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "West Bromwich Albion", "Southampton",
            "Leicester City", "Newcastle United", "Brighton and Hove Albion", "Swansea City", "Stoke City",
            "Huddersfield Town", "West Ham United", "Burnley"],
        "champion_ls": "Chelsea",
        "top5_ls": ["Chelsea", "Tottenham Hotspur", "Manchester City", "Liverpool", "Arsenal"],
        "bottom5_ls": ["Stoke City", "Crystal Palace", "Swansea City", "Burnley", "Watford"],
        "promoted_ts": ["Newcastle United", "Brighton and Hove Albion", "Huddersfield Town"]
    },
    2018: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "Wolverhampton Wanderers", "Southampton",
            "Leicester City", "Newcastle United", "Brighton and Hove Albion", "Cardiff City", "Fulham",
            "Huddersfield Town", "West Ham United", "Burnley"],
        "champion_ls": "Manchester City",
        "top5_ls": ["Manchester City", "Manchester United", "Tottenham Hotspur", "Liverpool", "Chelsea"],
        "bottom5_ls": ["West Ham United", "Watford", "Brighton and Hove Albion", "Huddersfield Town", "Southampton"],
        "promoted_ts": ["Wolverhampton Wanderers", "Cardiff City", "Fulham"]
    },
    2019: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "Wolverhampton Wanderers", "Southampton",
            "Leicester City", "Newcastle United", "Brighton and Hove Albion", "Norwich City", "Aston Villa",
            "Sheffield United", "West Ham United", "Burnley"],
        "champion_ls": "Manchester City",
        "top5_ls": ["Manchester City", "Liverpool", "Chelsea", "Tottenham Hotspur", "Arsenal"],
        "bottom5_ls": ["Newcastle United", "Bournemouth", "Burnley", "Southampton", "Brighton and Hove Albion"],
        "promoted_ts": ["Norwich City", "Aston Villa", "Sheffield United"]
    }
}

# %%
# -1 means L
# 0 means D
# 1 means W
def getResult(row):
    if (row["team_h_score"] == row["team_a_score"]):
        return 0;
    elif (row["at_home"] == 1 and row["team_h_score"] < row["team_a_score"]):
        return -1;
    elif (row["at_home"] == 1 and row["team_h_score"] > row["team_a_score"]):
        return 1;
    elif (row["at_home"] == 0 and row["team_h_score"] < row["team_a_score"]):
        return 1;
    elif (row["at_home"] == 0 and row["team_h_score"] > row["team_a_score"]):
        return -1;

# %%
# main columns
cols = ["season", "GW", "at_home", "player_id", "opponent_id", "champion_ls", "top5_ls", "bottom5_ls", "promoted_ts",
        "influence", "creativity", "threat", "ict_index"];

# %%
# to remove columns after data augmented
to_remove_cols = ["minutes", "goals_scored", "goals_conceded", "assists", "clean_sheets", "own_goals", "yellow_cards", "red_cards", "penalties_conceded", "penalties_saved", "penalties_missed",
       "saves", "dribbles", "attempted_passes", "bonus", "bps", "big_chances_created", "big_chances_missed",
       "clearances_blocks_interceptions", "completed_passes", "errors_leading_to_goal", "errors_leading_to_goal_attempt",
       "fouls", "key_passes", "offside", "open_play_crosses", "recoveries", "target_missed", "result"];

# %%
# reset column orders
reset_cols = ["season", "GW", "at_home", "player_id", "opponent_id", "champion_ls", "top5_ls", "bottom5_ls", 
              "promoted_ts", 'assists', 'assists_pgw', 'attempted_passes',
       'attempted_passes_pgw', 'big_chances_created',
       'big_chances_created_pgw', 'big_chances_missed',
       'big_chances_missed_pgw', 'bonus', 'bonus_pgw', 'bps',
       'bps_pgw', 'clean_sheets', 'clean_sheets_pgw',
       'clearances_blocks_interceptions',
       'clearances_blocks_interceptions_pgw', 'completed_passes',
       'completed_passes_pgw', 'creativity', 'creativity_pgw', 'dribbles',
       'dribbles_pgw', 'errors_leading_to_goal',
       'errors_leading_to_goal_attempt', 'errors_leading_to_goal_attempt_pgw',
       'errors_leading_to_goal_pgw', 'fouls', 'fouls_pgw', 'goals_conceded',
       'goals_conceded_pgw', 'goals_scored', 'goals_scored_pgw', 'ict_index',
       'ict_index_pgw', 'influence', 'influence_pgw', 'key_passes',
       'key_passes_pgw', 'minutes', 'minutes_pgw', 'offside', 'offside_pgw',
       'open_play_crosses', 'open_play_crosses_pgw','own_goals', 'own_goals_pgw', 'penalties_conceded',
       'penalties_conceded_pgw', 'penalties_missed', 'penalties_missed_pgw',
       'penalties_saved', 'penalties_saved_pgw','recoveries', 'recoveries_pgw', 'red_cards', 'red_cards_pgw', 'result_pgw', 'saves',
       'saves_pgw','target_missed', 'target_missed_pgw', 'threat',
       'threat_pgw','yellow_cards', 'yellow_cards_pgw', 'total_points_pgw', 'total_points']

# %%
# columns to fix - change the type of it to be int
cols_to_fix = ["GW", "at_home", "player_id", "opponent_id", "champion_ls", "top5_ls", "bottom5_ls", 
               "promoted_ts", "total_points"]

# %%
for season in seasons:
    print("Preparing data for season: {}".format(season));
    print('*' * 100);
    
    # set the target season as an int version: 2016-17 -> 2016
    target_season = int("".join(season.split("-")[:-1]));
    
    # get the list of teams in that season and sort them
    teams = teams_in_season[target_season]["teams"];
    teams.sort();
    
    # get the champions, top5, bottom5 and promoted teams for that season
    champion_ls = teams_in_season[target_season]["champion_ls"];
    top5_ls = teams_in_season[target_season]["champion_ls"];
    bottom5_ls = teams_in_season[target_season]["bottom5_ls"];
    promoted_ts = teams_in_season[target_season]["promoted_ts"];
    
    # change to the season data directory
    os.chdir(os.path.join(os.getcwd(), "..", "..", "data", season, "gws"));
    
    # read the merged dataframe
    df = pd.read_csv("merged_gw_data.csv");
    
    # change to the data directory in the dev folder
    os.chdir(current_dir);
    os.chdir(os.path.join(os.getcwd(), "..", "..", "dev", "data"));
    
    # set the season
    df["season"] = target_season;
    
    # set team from the list of teams that season
    print(">> Setting opponent team names ...");
    # %time df["team"] = df["opponent_team"].apply(lambda team: teams[team-1]);
    print("✓ Done.");
    
    # encode the teams into id
    print(">> Encoding opponent team names into team ids ...");
    # %time df["opponent_id"] = df["team"].apply(lambda team: team_id_df[team_id_df["team_name"] == team]["team_id"].iloc[0]);
    print("✓ Done.");
    
    # set column for is champions last season
    print(">> Creating column for champions last season ...");
    # %time df["champion_ls"] = df["team"].apply(lambda team: 1 if team == champion_ls else 0);
    print("✓ Done.");
    
    # set column for top 5 last season
    print(">> Creating column for top 5 last season ...");
    # %time df["top5_ls"] = df["team"].apply(lambda team: 1 if team in top5_ls else 0);
    print("✓ Done.");
    
    # set column for bottom 5 last season
    print(">> Creating column for bottom 5 last season ...");
    # %time df["bottom5_ls"] = df["team"].apply(lambda team: 1 if team in bottom5_ls else 0);
    print("✓ Done.");
    
    # set column for promoted teams this season
    print(">> Creating column for promoted teams this season ...");
    # %time df["promoted_ts"] = df["team"].apply(lambda team: 1 if team in promoted_ts else 0);
    print("✓ Done.");
    
    # drop the opponent team and team columns
    print(">> Dropping team and opponent_team columns ...");
    # %time df.drop(["team", "opponent_team"], axis=1, inplace=True);
    print("✓ Done.");
    
    # encode the players into id
    print(">> Encoding player names into player ids ...");
    # %time df["player_id"] = df["name"].apply(lambda player: player_id_df[player_id_df["player_name"] == player]["player_id"].iloc[0]);
    print("✓ Done.");
    
    # encode was_home into labels
    print(">> Encoding at home into boolean labels ...");
    # %time df["at_home"] = df["was_home"].apply(lambda at_home: 0 if not at_home else 1);
    print("✓ Done.");
    
    # encode the result into -1, 0, 1
    print(">> Creating a column for game result ...");
    # %time df["result"] = df.apply(lambda row: getResult(row), axis=1);
    print("✓ Done.");
    
    # drop the player name and was home columns
    print(">> Dropping player name and was home columns ...");
    # %time df.drop(["name", "was_home"], axis=1, inplace=True);
    print(">> Done.");
    
    # drop the id column
    if 'id' in df.columns:
        print(">> Dropping id columns ...");
        # %time df.drop(["id"], axis=1, inplace=True);
        print("✓ Done.");
        
    # set the target column
    target_col = ["total_points"];
    
    # set columns to be all the columns
    cols = cols + to_remove_cols + target_col;
    
    # create a subset dataframe with the new columns
    current_season = df[cols];
    
    # sort the subset dataframe
    current_season.sort_values(["GW"], inplace=True);
    current_season.reset_index(inplace=True, drop=True);
    
    # create target previous gameweek columns
    target_pgw = ["total_points", "ict_index", "influence", "creativity", "threat"];
    target_pgw = target_pgw + to_remove_cols;
    player_ids = np.unique(current_season["player_id"]);
    
    # create a new dataframe that will be augmented to
    new_df = pd.DataFrame(columns=list(current_season.columns));
    
    # loop through each unique player and augment the data
    print(">> Augmenting player data for each gameweek ...");
    print('-' * 50);
    for player_id in player_ids:
        now = time.time();
        df_ = current_season[current_season["player_id"] == player_id]
        df_.reset_index(inplace=True, drop=True)
        for index in range(len(df_)):
            instance = df_.iloc[index]
            gw = instance["GW"];
            for target in target_pgw:
                if (gw == 1 or index == 0):
                    df_.ix[index, "{}_pgw".format(target)] = 0
                else:
                    df_.ix[index, "{}_pgw".format(target)] = df_.iloc[index-1][target]
        new_df = new_df.append(df_)
        later = time.time();
        difference = int(later - now);
        print("Completed player id {} --- Time taken: {}s".format(player_id, difference));
    print("✓ Done.");
    print('-' * 50);
    
    # fix the indices
    new_df.reset_index(inplace=True, drop=True);
    
    # subset the reset columns
    new_df = new_df[reset_cols];
    
    # fix the reset columns
    for col in cols_to_fix:
        new_df[col] = new_df[col].astype(int)
    
    # save the dataframe
    filename = "{}-prepared-data.csv".format(target_season);
    new_df.to_csv(filename, index=False);
    
    print("Done preparing data for {}. File saved at: {}".format(season, os.path.join(os.getcwd(), filename)));
    print('*' * 100);
    print("\n");
    
    # switch back to the scripts directory
    os.chdir(current_dir);
# Out:
# Preparing data for season: 2016-17
# ****************************************************************************************************
# >> Setting opponent team names ...
# CPU times: user 4.57 ms, sys: 80 µs, total: 4.65 ms
# Wall time: 4.6 ms
# ✓ Done.
# >> Encoding opponent team names into team ids ...
# CPU times: user 15.6 s, sys: 176 ms, total: 15.8 s
# Wall time: 17.9 s
# ✓ Done.
# >> Creating column for champions last season ...
# CPU times: user 7.59 ms, sys: 186 µs, total: 7.78 ms
# Wall time: 7.66 ms
# ✓ Done.
# >> Creating column for top 5 last season ...
# CPU times: user 7.66 ms, sys: 117 µs, total: 7.78 ms
# Wall time: 7.69 ms
# ✓ Done.
# >> Creating column for bottom 5 last season ...
# CPU times: user 8.55 ms, sys: 210 µs, total: 8.76 ms
# Wall time: 8.64 ms
# ✓ Done.
# >> Creating column for promoted teams this season ...
# CPU times: user 7.91 ms, sys: 69 µs, total: 7.98 ms
# Wall time: 7.91 ms
# ✓ Done.
# >> Dropping team and opponent_team columns ...
# CPU times: user 9.74 ms, sys: 6.55 ms, total: 16.3 ms
# Wall time: 15.3 ms
# ✓ Done.
# >> Encoding player names into player ids ...
# CPU times: user 17.5 s, sys: 238 ms, total: 17.7 s
# Wall time: 20.6 s
# ✓ Done.
# >> Encoding at home into boolean labels ...
# CPU times: user 8.8 ms, sys: 375 µs, total: 9.18 ms
# Wall time: 8.98 ms
# ✓ Done.
# >> Creating a column for game result ...
# CPU times: user 1.7 s, sys: 40.4 ms, total: 1.74 s
# Wall time: 1.87 s
# ✓ Done.
# >> Dropping player name and was home columns ...
# CPU times: user 7.02 ms, sys: 3.35 ms, total: 10.4 ms
# Wall time: 9.83 ms
# >> Done.
# >> Dropping id columns ...
# CPU times: user 2.85 ms, sys: 1.22 ms, total: 4.07 ms
# Wall time: 4.05 ms
# ✓ Done.
# >> Augmenting player data for each gameweek ...
# --------------------------------------------------
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:125: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:127: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:6701: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Completed player id 1 --- Time taken: 39s
# Completed player id 2 --- Time taken: 39s
# Completed player id 3 --- Time taken: 1s
# Completed player id 4 --- Time taken: 41s
# Completed player id 5 --- Time taken: 22s
# Completed player id 6 --- Time taken: 34s
# Completed player id 7 --- Time taken: 34s
# Completed player id 8 --- Time taken: 35s
# Completed player id 9 --- Time taken: 36s
# Completed player id 10 --- Time taken: 37s
# Completed player id 11 --- Time taken: 38s
# Completed player id 12 --- Time taken: 38s
# Completed player id 13 --- Time taken: 39s
# Completed player id 14 --- Time taken: 35s
# Completed player id 15 --- Time taken: 34s
# Completed player id 16 --- Time taken: 34s
# Completed player id 17 --- Time taken: 30s
# Completed player id 18 --- Time taken: 16s
# Completed player id 19 --- Time taken: 33s
# Completed player id 20 --- Time taken: 34s
# Completed player id 21 --- Time taken: 31s
# Completed player id 22 --- Time taken: 34s
# Completed player id 23 --- Time taken: 33s
# Completed player id 24 --- Time taken: 34s
# Completed player id 25 --- Time taken: 33s
# Completed player id 26 --- Time taken: 27s
# Completed player id 27 --- Time taken: 34s
# Completed player id 28 --- Time taken: 34s
# Completed player id 29 --- Time taken: 31s
# Completed player id 30 --- Time taken: 41s
# Completed player id 31 --- Time taken: 28s
# Completed player id 32 --- Time taken: 39s
# Completed player id 33 --- Time taken: 31s
# Completed player id 34 --- Time taken: 31s
# Completed player id 35 --- Time taken: 30s
# Completed player id 36 --- Time taken: 20s
# Completed player id 37 --- Time taken: 18s
# Completed player id 38 --- Time taken: 29s
# Completed player id 39 --- Time taken: 34s
# Completed player id 40 --- Time taken: 29s
# Completed player id 41 --- Time taken: 36s
# Completed player id 42 --- Time taken: 17s
# Completed player id 43 --- Time taken: 44s
# Completed player id 44 --- Time taken: 31s
# Completed player id 45 --- Time taken: 30s
# Completed player id 46 --- Time taken: 29s
# Completed player id 47 --- Time taken: 30s
# Completed player id 48 --- Time taken: 12s
# Completed player id 49 --- Time taken: 30s
# Completed player id 50 --- Time taken: 20s
# Completed player id 51 --- Time taken: 30s
# Completed player id 52 --- Time taken: 28s
# Completed player id 53 --- Time taken: 27s
# Completed player id 54 --- Time taken: 30s
# Completed player id 55 --- Time taken: 37s
# Completed player id 56 --- Time taken: 35s
# Completed player id 57 --- Time taken: 2s
# Completed player id 58 --- Time taken: 48s
# Completed player id 59 --- Time taken: 35s
# Completed player id 60 --- Time taken: 5s
# Completed player id 61 --- Time taken: 35s
# Completed player id 62 --- Time taken: 36s
# Completed player id 63 --- Time taken: 35s
# Completed player id 64 --- Time taken: 35s
# Completed player id 65 --- Time taken: 33s
# Completed player id 66 --- Time taken: 34s
# Completed player id 67 --- Time taken: 34s
# Completed player id 68 --- Time taken: 34s
# Completed player id 69 --- Time taken: 14s
# Completed player id 70 --- Time taken: 42s
# Completed player id 71 --- Time taken: 43s
# Completed player id 72 --- Time taken: 37s
# Completed player id 73 --- Time taken: 10s
# Completed player id 74 --- Time taken: 35s
# Completed player id 75 --- Time taken: 35s
# Completed player id 76 --- Time taken: 14s
# Completed player id 77 --- Time taken: 34s
# Completed player id 78 --- Time taken: 36s
# Completed player id 79 --- Time taken: 35s
# Completed player id 80 --- Time taken: 34s
# Completed player id 81 --- Time taken: 34s
# Completed player id 82 --- Time taken: 33s
# Completed player id 83 --- Time taken: 34s
# Completed player id 84 --- Time taken: 30s
# Completed player id 85 --- Time taken: 32s
# Completed player id 86 --- Time taken: 34s
# Completed player id 87 --- Time taken: 34s
# Completed player id 88 --- Time taken: 23s
# Completed player id 89 --- Time taken: 30s
# Completed player id 90 --- Time taken: 35s
# Completed player id 91 --- Time taken: 35s
# Completed player id 92 --- Time taken: 34s
# Completed player id 93 --- Time taken: 33s
# Completed player id 94 --- Time taken: 35s
# Completed player id 95 --- Time taken: 34s
# Completed player id 96 --- Time taken: 34s
# Completed player id 97 --- Time taken: 34s
# Completed player id 98 --- Time taken: 34s
# Completed player id 99 --- Time taken: 34s
# Completed player id 100 --- Time taken: 18s
# Completed player id 101 --- Time taken: 34s
# Completed player id 102 --- Time taken: 34s
# Completed player id 103 --- Time taken: 33s
# Completed player id 104 --- Time taken: 34s
# Completed player id 105 --- Time taken: 31s
# Completed player id 106 --- Time taken: 34s
# Completed player id 107 --- Time taken: 34s
# Completed player id 108 --- Time taken: 34s
# Completed player id 109 --- Time taken: 34s
# Completed player id 110 --- Time taken: 34s
# Completed player id 111 --- Time taken: 34s
# Completed player id 112 --- Time taken: 34s
# Completed player id 113 --- Time taken: 33s
# Completed player id 114 --- Time taken: 18s
# Completed player id 115 --- Time taken: 33s
# Completed player id 116 --- Time taken: 33s
# Completed player id 117 --- Time taken: 34s
# Completed player id 118 --- Time taken: 33s
# Completed player id 119 --- Time taken: 34s
# Completed player id 120 --- Time taken: 18s
# Completed player id 121 --- Time taken: 34s
# Completed player id 122 --- Time taken: 33s
# Completed player id 123 --- Time taken: 33s
# Completed player id 124 --- Time taken: 34s
# Completed player id 125 --- Time taken: 35s
# Completed player id 126 --- Time taken: 34s
# Completed player id 127 --- Time taken: 35s
# Completed player id 128 --- Time taken: 34s
# Completed player id 129 --- Time taken: 34s
# Completed player id 130 --- Time taken: 34s
# Completed player id 131 --- Time taken: 32s
# Completed player id 132 --- Time taken: 34s
# Completed player id 133 --- Time taken: 34s
# Completed player id 134 --- Time taken: 34s
# Completed player id 135 --- Time taken: 9s
# Completed player id 136 --- Time taken: 34s
# Completed player id 137 --- Time taken: 34s
# Completed player id 138 --- Time taken: 34s
# Completed player id 139 --- Time taken: 34s
# Completed player id 140 --- Time taken: 34s
# Completed player id 141 --- Time taken: 34s
# Completed player id 142 --- Time taken: 34s
# Completed player id 143 --- Time taken: 35s
# Completed player id 144 --- Time taken: 33s
# Completed player id 145 --- Time taken: 33s
# Completed player id 146 --- Time taken: 34s
# Completed player id 147 --- Time taken: 34s
# Completed player id 148 --- Time taken: 34s
# Completed player id 149 --- Time taken: 10s
# Completed player id 150 --- Time taken: 33s
# Completed player id 151 --- Time taken: 35s
# Completed player id 152 --- Time taken: 12s
# Completed player id 153 --- Time taken: 34s
# Completed player id 154 --- Time taken: 34s
# Completed player id 155 --- Time taken: 1s
# Completed player id 156 --- Time taken: 34s
# Completed player id 157 --- Time taken: 25s
# Completed player id 158 --- Time taken: 1s
# Completed player id 159 --- Time taken: 34s
# Completed player id 160 --- Time taken: 34s
# Completed player id 161 --- Time taken: 34s
# Completed player id 162 --- Time taken: 34s
# Completed player id 163 --- Time taken: 34s
# Completed player id 164 --- Time taken: 34s
# Completed player id 165 --- Time taken: 34s
# Completed player id 166 --- Time taken: 33s
# Completed player id 167 --- Time taken: 34s
# Completed player id 168 --- Time taken: 32s
# Completed player id 169 --- Time taken: 34s
# Completed player id 170 --- Time taken: 31s
# Completed player id 171 --- Time taken: 31s
# Completed player id 172 --- Time taken: 34s
# Completed player id 173 --- Time taken: 34s
# Completed player id 174 --- Time taken: 34s
# Completed player id 175 --- Time taken: 33s
# Completed player id 176 --- Time taken: 33s
# Completed player id 177 --- Time taken: 33s
# Completed player id 178 --- Time taken: 34s
# Completed player id 179 --- Time taken: 19s
# Completed player id 180 --- Time taken: 34s
# Completed player id 181 --- Time taken: 34s
# Completed player id 182 --- Time taken: 3s
# Completed player id 183 --- Time taken: 33s
# Completed player id 184 --- Time taken: 31s
# Completed player id 185 --- Time taken: 34s
# Completed player id 186 --- Time taken: 31s
# Completed player id 187 --- Time taken: 34s
# Completed player id 188 --- Time taken: 33s
# Completed player id 189 --- Time taken: 8s
# Completed player id 190 --- Time taken: 33s
# Completed player id 191 --- Time taken: 34s
# Completed player id 192 --- Time taken: 21s
# Completed player id 193 --- Time taken: 27s
# Completed player id 194 --- Time taken: 28s
# Completed player id 195 --- Time taken: 33s
# Completed player id 196 --- Time taken: 33s
# Completed player id 197 --- Time taken: 34s
# Completed player id 198 --- Time taken: 34s
# Completed player id 199 --- Time taken: 35s
# Completed player id 200 --- Time taken: 32s
# Completed player id 201 --- Time taken: 7s
# Completed player id 202 --- Time taken: 34s
# Completed player id 203 --- Time taken: 33s
# Completed player id 204 --- Time taken: 19s
# Completed player id 205 --- Time taken: 3s
# Completed player id 206 --- Time taken: 34s
# Completed player id 207 --- Time taken: 33s
# Completed player id 208 --- Time taken: 33s
# Completed player id 209 --- Time taken: 34s
# Completed player id 210 --- Time taken: 35s
# Completed player id 211 --- Time taken: 34s
# Completed player id 212 --- Time taken: 34s
# Completed player id 213 --- Time taken: 33s
# Completed player id 214 --- Time taken: 20s
# Completed player id 215 --- Time taken: 34s
# Completed player id 216 --- Time taken: 34s
# Completed player id 217 --- Time taken: 16s
# Completed player id 218 --- Time taken: 31s
# Completed player id 219 --- Time taken: 34s
# Completed player id 220 --- Time taken: 33s
# Completed player id 221 --- Time taken: 33s
# Completed player id 222 --- Time taken: 34s
# Completed player id 223 --- Time taken: 34s
# Completed player id 224 --- Time taken: 34s
# Completed player id 225 --- Time taken: 34s
# Completed player id 226 --- Time taken: 3s
# Completed player id 227 --- Time taken: 34s
# Completed player id 228 --- Time taken: 33s
# Completed player id 229 --- Time taken: 34s
# Completed player id 230 --- Time taken: 34s
# Completed player id 231 --- Time taken: 34s
# Completed player id 232 --- Time taken: 33s
# Completed player id 233 --- Time taken: 33s
# Completed player id 234 --- Time taken: 16s
# Completed player id 235 --- Time taken: 33s
# Completed player id 236 --- Time taken: 34s
# Completed player id 237 --- Time taken: 33s
# Completed player id 238 --- Time taken: 33s
# Completed player id 239 --- Time taken: 33s
# Completed player id 240 --- Time taken: 34s
# Completed player id 241 --- Time taken: 34s
# Completed player id 242 --- Time taken: 33s
# Completed player id 243 --- Time taken: 28s
# Completed player id 244 --- Time taken: 30s
# Completed player id 245 --- Time taken: 34s
# Completed player id 246 --- Time taken: 34s
# Completed player id 247 --- Time taken: 1s
# Completed player id 248 --- Time taken: 34s
# Completed player id 249 --- Time taken: 15s
# Completed player id 250 --- Time taken: 33s
# Completed player id 251 --- Time taken: 34s
# Completed player id 252 --- Time taken: 33s
# Completed player id 253 --- Time taken: 35s
# Completed player id 254 --- Time taken: 34s
# Completed player id 255 --- Time taken: 34s
# Completed player id 256 --- Time taken: 34s
# Completed player id 257 --- Time taken: 34s
# Completed player id 258 --- Time taken: 33s
# Completed player id 259 --- Time taken: 33s
# Completed player id 260 --- Time taken: 34s
# Completed player id 261 --- Time taken: 32s
# Completed player id 262 --- Time taken: 34s
# Completed player id 263 --- Time taken: 33s
# Completed player id 264 --- Time taken: 33s
# Completed player id 265 --- Time taken: 17s
# Completed player id 266 --- Time taken: 34s
# Completed player id 267 --- Time taken: 10s
# Completed player id 268 --- Time taken: 34s
# Completed player id 269 --- Time taken: 34s
# Completed player id 270 --- Time taken: 34s
# Completed player id 271 --- Time taken: 34s
# Completed player id 272 --- Time taken: 31s
# Completed player id 273 --- Time taken: 34s
# Completed player id 274 --- Time taken: 33s
# Completed player id 275 --- Time taken: 34s
# Completed player id 276 --- Time taken: 34s
# Completed player id 277 --- Time taken: 34s
# Completed player id 278 --- Time taken: 34s
# Completed player id 279 --- Time taken: 33s
# Completed player id 280 --- Time taken: 33s
# Completed player id 281 --- Time taken: 31s
# Completed player id 282 --- Time taken: 34s
# Completed player id 283 --- Time taken: 34s
# Completed player id 284 --- Time taken: 33s
# Completed player id 285 --- Time taken: 32s
# Completed player id 286 --- Time taken: 34s
# Completed player id 287 --- Time taken: 34s
# Completed player id 288 --- Time taken: 30s
# Completed player id 289 --- Time taken: 33s
# Completed player id 290 --- Time taken: 34s
# Completed player id 291 --- Time taken: 34s
# Completed player id 292 --- Time taken: 34s
# Completed player id 293 --- Time taken: 8s
# Completed player id 294 --- Time taken: 33s
# Completed player id 295 --- Time taken: 34s
# Completed player id 296 --- Time taken: 34s
# Completed player id 297 --- Time taken: 34s
# Completed player id 298 --- Time taken: 33s
# Completed player id 299 --- Time taken: 34s
# Completed player id 300 --- Time taken: 34s
# Completed player id 301 --- Time taken: 34s
# Completed player id 302 --- Time taken: 31s
# Completed player id 303 --- Time taken: 34s
# Completed player id 304 --- Time taken: 33s
# Completed player id 305 --- Time taken: 33s
# Completed player id 306 --- Time taken: 33s
# Completed player id 307 --- Time taken: 34s
# Completed player id 308 --- Time taken: 33s
# Completed player id 309 --- Time taken: 34s
# Completed player id 310 --- Time taken: 32s
# Completed player id 311 --- Time taken: 34s
# Completed player id 312 --- Time taken: 33s
# Completed player id 313 --- Time taken: 31s
# Completed player id 314 --- Time taken: 28s
# Completed player id 315 --- Time taken: 34s
# Completed player id 316 --- Time taken: 33s
# Completed player id 317 --- Time taken: 34s
# Completed player id 318 --- Time taken: 34s
# Completed player id 319 --- Time taken: 34s
# Completed player id 320 --- Time taken: 34s
# Completed player id 321 --- Time taken: 34s
# Completed player id 322 --- Time taken: 34s
# Completed player id 323 --- Time taken: 34s
# Completed player id 324 --- Time taken: 34s
# Completed player id 325 --- Time taken: 8s
# Completed player id 326 --- Time taken: 8s
# Completed player id 327 --- Time taken: 34s
# Completed player id 328 --- Time taken: 34s
# Completed player id 329 --- Time taken: 33s
# Completed player id 330 --- Time taken: 33s
# Completed player id 331 --- Time taken: 17s
# Completed player id 332 --- Time taken: 34s
# Completed player id 333 --- Time taken: 16s
# Completed player id 334 --- Time taken: 34s
# Completed player id 335 --- Time taken: 33s
# Completed player id 336 --- Time taken: 34s
# Completed player id 337 --- Time taken: 34s
# Completed player id 338 --- Time taken: 33s
# Completed player id 339 --- Time taken: 14s
# Completed player id 340 --- Time taken: 34s
# Completed player id 341 --- Time taken: 34s
# Completed player id 342 --- Time taken: 31s
# Completed player id 343 --- Time taken: 33s
# Completed player id 344 --- Time taken: 34s
# Completed player id 345 --- Time taken: 35s
# Completed player id 346 --- Time taken: 34s
# Completed player id 347 --- Time taken: 19s
# Completed player id 348 --- Time taken: 33s
# Completed player id 349 --- Time taken: 13s
# Completed player id 350 --- Time taken: 38s
# Completed player id 351 --- Time taken: 44s
# Completed player id 352 --- Time taken: 37s
# Completed player id 353 --- Time taken: 35s
# Completed player id 354 --- Time taken: 35s
# Completed player id 355 --- Time taken: 38s
# Completed player id 356 --- Time taken: 37s
# Completed player id 357 --- Time taken: 34s
# Completed player id 358 --- Time taken: 33s
# Completed player id 359 --- Time taken: 34s
# Completed player id 360 --- Time taken: 34s
# Completed player id 361 --- Time taken: 34s
# Completed player id 362 --- Time taken: 34s
# Completed player id 363 --- Time taken: 21s
# Completed player id 364 --- Time taken: 33s
# Completed player id 365 --- Time taken: 34s
# Completed player id 366 --- Time taken: 1s
# Completed player id 367 --- Time taken: 34s
# Completed player id 368 --- Time taken: 33s
# Completed player id 369 --- Time taken: 23s
# Completed player id 370 --- Time taken: 33s
# Completed player id 371 --- Time taken: 34s
# Completed player id 372 --- Time taken: 34s
# Completed player id 373 --- Time taken: 34s
# Completed player id 374 --- Time taken: 34s
# Completed player id 375 --- Time taken: 33s
# Completed player id 376 --- Time taken: 32s
# Completed player id 377 --- Time taken: 32s
# Completed player id 378 --- Time taken: 34s
# Completed player id 379 --- Time taken: 34s
# Completed player id 380 --- Time taken: 14s
# Completed player id 381 --- Time taken: 34s
# Completed player id 382 --- Time taken: 34s
# Completed player id 383 --- Time taken: 34s
# Completed player id 384 --- Time taken: 34s
# Completed player id 385 --- Time taken: 34s
# Completed player id 386 --- Time taken: 27s
# Completed player id 387 --- Time taken: 33s
# Completed player id 388 --- Time taken: 34s
# Completed player id 389 --- Time taken: 34s
# Completed player id 390 --- Time taken: 33s
# Completed player id 391 --- Time taken: 1s
# Completed player id 392 --- Time taken: 34s
# Completed player id 393 --- Time taken: 34s
# Completed player id 394 --- Time taken: 33s
# Completed player id 395 --- Time taken: 34s
# Completed player id 396 --- Time taken: 34s
# Completed player id 397 --- Time taken: 33s
# Completed player id 398 --- Time taken: 33s
# Completed player id 399 --- Time taken: 33s
# Completed player id 400 --- Time taken: 34s
# Completed player id 401 --- Time taken: 32s
# Completed player id 402 --- Time taken: 34s
# Completed player id 403 --- Time taken: 34s
# Completed player id 404 --- Time taken: 34s
# Completed player id 405 --- Time taken: 34s
# Completed player id 406 --- Time taken: 33s
# Completed player id 407 --- Time taken: 34s
# Completed player id 408 --- Time taken: 34s
# Completed player id 409 --- Time taken: 34s
# Completed player id 410 --- Time taken: 30s
# Completed player id 411 --- Time taken: 34s
# Completed player id 412 --- Time taken: 33s
# Completed player id 413 --- Time taken: 32s
# Completed player id 414 --- Time taken: 15s
# Completed player id 415 --- Time taken: 34s
# Completed player id 416 --- Time taken: 14s
# Completed player id 417 --- Time taken: 33s
# Completed player id 418 --- Time taken: 33s
# Completed player id 419 --- Time taken: 31s
# Completed player id 420 --- Time taken: 33s
# Completed player id 421 --- Time taken: 33s
# Completed player id 422 --- Time taken: 33s
# Completed player id 423 --- Time taken: 34s
# Completed player id 424 --- Time taken: 15s
# Completed player id 425 --- Time taken: 33s
# Completed player id 426 --- Time taken: 32s
# Completed player id 427 --- Time taken: 35s
# Completed player id 428 --- Time taken: 34s
# Completed player id 429 --- Time taken: 33s
# Completed player id 430 --- Time taken: 14s
# Completed player id 431 --- Time taken: 33s
# Completed player id 432 --- Time taken: 35s
# Completed player id 433 --- Time taken: 34s
# Completed player id 434 --- Time taken: 35s
# Completed player id 435 --- Time taken: 34s
# Completed player id 436 --- Time taken: 34s
# Completed player id 437 --- Time taken: 34s
# Completed player id 438 --- Time taken: 34s
# Completed player id 439 --- Time taken: 31s
# Completed player id 440 --- Time taken: 34s
# Completed player id 441 --- Time taken: 22s
# Completed player id 442 --- Time taken: 34s
# Completed player id 443 --- Time taken: 34s
# Completed player id 444 --- Time taken: 33s
# Completed player id 445 --- Time taken: 34s
# Completed player id 446 --- Time taken: 33s
# Completed player id 447 --- Time taken: 34s
# Completed player id 448 --- Time taken: 31s
# Completed player id 449 --- Time taken: 34s
# Completed player id 450 --- Time taken: 34s
# Completed player id 451 --- Time taken: 33s
# Completed player id 452 --- Time taken: 15s
# Completed player id 453 --- Time taken: 12s
# Completed player id 454 --- Time taken: 34s
# Completed player id 455 --- Time taken: 34s
# Completed player id 456 --- Time taken: 33s
# Completed player id 457 --- Time taken: 28s
# Completed player id 458 --- Time taken: 34s
# Completed player id 459 --- Time taken: 31s
# Completed player id 460 --- Time taken: 9s
# Completed player id 461 --- Time taken: 33s
# Completed player id 462 --- Time taken: 34s
# Completed player id 463 --- Time taken: 34s
# Completed player id 464 --- Time taken: 34s
# Completed player id 465 --- Time taken: 24s
# Completed player id 466 --- Time taken: 35s
# Completed player id 467 --- Time taken: 34s
# Completed player id 468 --- Time taken: 10s
# Completed player id 469 --- Time taken: 1s
# Completed player id 470 --- Time taken: 15s
# Completed player id 471 --- Time taken: 35s
# Completed player id 472 --- Time taken: 34s
# Completed player id 473 --- Time taken: 34s
# Completed player id 474 --- Time taken: 34s
# Completed player id 475 --- Time taken: 33s
# Completed player id 476 --- Time taken: 34s
# Completed player id 477 --- Time taken: 18s
# Completed player id 478 --- Time taken: 34s
# Completed player id 479 --- Time taken: 35s
# Completed player id 480 --- Time taken: 18s
# Completed player id 481 --- Time taken: 22s
# Completed player id 482 --- Time taken: 32s
# Completed player id 483 --- Time taken: 34s
# Completed player id 484 --- Time taken: 35s
# Completed player id 485 --- Time taken: 35s
# Completed player id 486 --- Time taken: 36s
# Completed player id 487 --- Time taken: 35s
# Completed player id 488 --- Time taken: 35s
# Completed player id 489 --- Time taken: 35s
# Completed player id 490 --- Time taken: 34s
# Completed player id 491 --- Time taken: 35s
# Completed player id 492 --- Time taken: 15s
# Completed player id 493 --- Time taken: 35s
# Completed player id 494 --- Time taken: 5s
# Completed player id 495 --- Time taken: 36s
# Completed player id 496 --- Time taken: 13s
# Completed player id 497 --- Time taken: 35s
# Completed player id 498 --- Time taken: 33s
# Completed player id 499 --- Time taken: 36s
# Completed player id 500 --- Time taken: 36s
# Completed player id 501 --- Time taken: 36s
# Completed player id 502 --- Time taken: 35s
# Completed player id 503 --- Time taken: 35s
# Completed player id 504 --- Time taken: 35s
# Completed player id 505 --- Time taken: 36s
# Completed player id 506 --- Time taken: 35s
# Completed player id 507 --- Time taken: 5s
# Completed player id 508 --- Time taken: 35s
# Completed player id 509 --- Time taken: 34s
# Completed player id 510 --- Time taken: 35s
# Completed player id 511 --- Time taken: 36s
# Completed player id 512 --- Time taken: 36s
# Completed player id 513 --- Time taken: 35s
# Completed player id 514 --- Time taken: 35s
# Completed player id 515 --- Time taken: 22s
# Completed player id 516 --- Time taken: 36s
# Completed player id 517 --- Time taken: 35s
# Completed player id 518 --- Time taken: 35s
# Completed player id 519 --- Time taken: 35s
# Completed player id 520 --- Time taken: 36s
# Completed player id 521 --- Time taken: 34s
# Completed player id 522 --- Time taken: 35s
# Completed player id 523 --- Time taken: 30s
# Completed player id 524 --- Time taken: 35s
# Completed player id 525 --- Time taken: 23s
# Completed player id 526 --- Time taken: 16s
# Completed player id 527 --- Time taken: 35s
# Completed player id 528 --- Time taken: 35s
# Completed player id 529 --- Time taken: 35s
# Completed player id 530 --- Time taken: 31s
# Completed player id 531 --- Time taken: 35s
# Completed player id 532 --- Time taken: 35s
# Completed player id 533 --- Time taken: 35s
# Completed player id 534 --- Time taken: 35s
# Completed player id 535 --- Time taken: 33s
# Completed player id 536 --- Time taken: 35s
# Completed player id 537 --- Time taken: 35s
# Completed player id 538 --- Time taken: 33s
# Completed player id 539 --- Time taken: 35s
# Completed player id 540 --- Time taken: 33s
# Completed player id 541 --- Time taken: 33s
# Completed player id 542 --- Time taken: 33s
# Completed player id 543 --- Time taken: 33s
# Completed player id 544 --- Time taken: 33s
# Completed player id 545 --- Time taken: 33s
# Completed player id 546 --- Time taken: 34s
# Completed player id 547 --- Time taken: 34s
# Completed player id 548 --- Time taken: 33s
# Completed player id 549 --- Time taken: 34s
# Completed player id 550 --- Time taken: 33s
# Completed player id 551 --- Time taken: 33s
# Completed player id 552 --- Time taken: 33s
# Completed player id 553 --- Time taken: 33s
# Completed player id 554 --- Time taken: 33s
# Completed player id 555 --- Time taken: 32s
# Completed player id 556 --- Time taken: 33s
# Completed player id 557 --- Time taken: 33s
# Completed player id 558 --- Time taken: 28s
# Completed player id 559 --- Time taken: 33s
# Completed player id 560 --- Time taken: 34s
# Completed player id 561 --- Time taken: 21s
# Completed player id 562 --- Time taken: 1s
# Completed player id 563 --- Time taken: 5s
# Completed player id 564 --- Time taken: 35s
# Completed player id 565 --- Time taken: 34s
# Completed player id 566 --- Time taken: 34s
# Completed player id 567 --- Time taken: 33s
# Completed player id 568 --- Time taken: 13s
# Completed player id 569 --- Time taken: 34s
# Completed player id 570 --- Time taken: 34s
# Completed player id 571 --- Time taken: 34s
# Completed player id 572 --- Time taken: 34s
# Completed player id 573 --- Time taken: 32s
# Completed player id 574 --- Time taken: 34s
# Completed player id 575 --- Time taken: 35s
# Completed player id 576 --- Time taken: 33s
# Completed player id 577 --- Time taken: 34s
# Completed player id 578 --- Time taken: 33s
# Completed player id 579 --- Time taken: 16s
# Completed player id 580 --- Time taken: 24s
# Completed player id 581 --- Time taken: 34s
# Completed player id 582 --- Time taken: 33s
# Completed player id 583 --- Time taken: 34s
# Completed player id 584 --- Time taken: 34s
# Completed player id 585 --- Time taken: 34s
# Completed player id 586 --- Time taken: 34s
# Completed player id 587 --- Time taken: 34s
# Completed player id 588 --- Time taken: 34s
# Completed player id 589 --- Time taken: 34s
# Completed player id 590 --- Time taken: 34s
# Completed player id 591 --- Time taken: 28s
# Completed player id 592 --- Time taken: 1s
# Completed player id 593 --- Time taken: 34s
# Completed player id 594 --- Time taken: 33s
# Completed player id 595 --- Time taken: 3s
# Completed player id 596 --- Time taken: 34s
# Completed player id 597 --- Time taken: 34s
# Completed player id 598 --- Time taken: 34s
# Completed player id 599 --- Time taken: 5s
# Completed player id 600 --- Time taken: 34s
# Completed player id 601 --- Time taken: 34s
# Completed player id 602 --- Time taken: 33s
# Completed player id 603 --- Time taken: 34s
# Completed player id 604 --- Time taken: 33s
# Completed player id 605 --- Time taken: 34s
# Completed player id 606 --- Time taken: 33s
# Completed player id 607 --- Time taken: 34s
# Completed player id 608 --- Time taken: 34s
# Completed player id 609 --- Time taken: 33s
# Completed player id 610 --- Time taken: 34s
# Completed player id 611 --- Time taken: 31s
# Completed player id 612 --- Time taken: 33s
# Completed player id 613 --- Time taken: 33s
# Completed player id 614 --- Time taken: 31s
# Completed player id 615 --- Time taken: 30s
# Completed player id 616 --- Time taken: 32s
# Completed player id 617 --- Time taken: 31s
# Completed player id 618 --- Time taken: 33s
# Completed player id 619 --- Time taken: 33s
# Completed player id 620 --- Time taken: 34s
# Completed player id 621 --- Time taken: 33s
# Completed player id 622 --- Time taken: 34s
# Completed player id 623 --- Time taken: 34s
# Completed player id 624 --- Time taken: 34s
# Completed player id 625 --- Time taken: 33s
# Completed player id 626 --- Time taken: 33s
# Completed player id 627 --- Time taken: 34s
# Completed player id 628 --- Time taken: 26s
# Completed player id 629 --- Time taken: 34s
# Completed player id 630 --- Time taken: 34s
# Completed player id 631 --- Time taken: 34s
# Completed player id 632 --- Time taken: 33s
# Completed player id 633 --- Time taken: 34s
# Completed player id 634 --- Time taken: 34s
# Completed player id 635 --- Time taken: 25s
# Completed player id 636 --- Time taken: 34s
# Completed player id 637 --- Time taken: 14s
# Completed player id 638 --- Time taken: 33s
# Completed player id 639 --- Time taken: 34s
# Completed player id 640 --- Time taken: 34s
# Completed player id 641 --- Time taken: 34s
# Completed player id 642 --- Time taken: 34s
# Completed player id 643 --- Time taken: 34s
# Completed player id 644 --- Time taken: 33s
# Completed player id 645 --- Time taken: 34s
# Completed player id 646 --- Time taken: 34s
# Completed player id 647 --- Time taken: 33s
# Completed player id 648 --- Time taken: 33s
# Completed player id 649 --- Time taken: 34s
# Completed player id 650 --- Time taken: 33s
# Completed player id 651 --- Time taken: 34s
# Completed player id 652 --- Time taken: 34s
# Completed player id 653 --- Time taken: 31s
# Completed player id 654 --- Time taken: 34s
# Completed player id 655 --- Time taken: 34s
# Completed player id 656 --- Time taken: 33s
# Completed player id 657 --- Time taken: 34s
# Completed player id 658 --- Time taken: 33s
# Completed player id 659 --- Time taken: 34s
# Completed player id 660 --- Time taken: 33s
# Completed player id 661 --- Time taken: 34s
# Completed player id 662 --- Time taken: 34s
# Completed player id 663 --- Time taken: 34s
# Completed player id 664 --- Time taken: 35s
# Completed player id 665 --- Time taken: 34s
# Completed player id 666 --- Time taken: 33s
# Completed player id 667 --- Time taken: 16s
# Completed player id 668 --- Time taken: 34s
# Completed player id 669 --- Time taken: 34s
# Completed player id 670 --- Time taken: 32s
# Completed player id 671 --- Time taken: 33s
# Completed player id 672 --- Time taken: 34s
# Completed player id 673 --- Time taken: 34s
# Completed player id 674 --- Time taken: 33s
# Completed player id 675 --- Time taken: 34s
# Completed player id 676 --- Time taken: 34s
# Completed player id 677 --- Time taken: 33s
# Completed player id 678 --- Time taken: 34s
# Completed player id 679 --- Time taken: 35s
# Completed player id 680 --- Time taken: 1s
# Completed player id 681 --- Time taken: 35s
# Completed player id 682 --- Time taken: 32s
# Completed player id 683 --- Time taken: 33s
# ✓ Done.
# --------------------------------------------------
# Done preparing data for 2016-17. File saved at: /Users/sakib@ibm.com/workspace/other/projects/Fantasy-Premier-League/dev/data/2016-prepared-data.csv
# ****************************************************************************************************
#
#
# Preparing data for season: 2017-18
# ****************************************************************************************************
# >> Setting opponent team names ...
# CPU times: user 6.04 ms, sys: 114 µs, total: 6.15 ms
# Wall time: 6.1 ms
# ✓ Done.
# >> Encoding opponent team names into team ids ...
# CPU times: user 14.8 s, sys: 190 ms, total: 15 s
# Wall time: 16.8 s
# ✓ Done.
# >> Creating column for champions last season ...
# CPU times: user 7.23 ms, sys: 133 µs, total: 7.36 ms
# Wall time: 7.27 ms
# ✓ Done.
# >> Creating column for top 5 last season ...
# CPU times: user 6.61 ms, sys: 34 µs, total: 6.64 ms
# Wall time: 6.61 ms
# ✓ Done.
# >> Creating column for bottom 5 last season ...
# CPU times: user 8.73 ms, sys: 276 µs, total: 9 ms
# Wall time: 8.8 ms
# ✓ Done.
# >> Creating column for promoted teams this season ...
# CPU times: user 7.7 ms, sys: 125 µs, total: 7.83 ms
# Wall time: 7.75 ms
# ✓ Done.
# >> Dropping team and opponent_team columns ...
# CPU times: user 12 ms, sys: 18.5 ms, total: 30.5 ms
# Wall time: 41.4 ms
# ✓ Done.
# >> Encoding player names into player ids ...
# CPU times: user 16.3 s, sys: 214 ms, total: 16.5 s
# Wall time: 19.2 s
# ✓ Done.
# >> Encoding at home into boolean labels ...
# CPU times: user 10.3 ms, sys: 397 µs, total: 10.7 ms
# Wall time: 12.4 ms
# ✓ Done.
# >> Creating a column for game result ...
# CPU times: user 1.46 s, sys: 38 ms, total: 1.5 s
# Wall time: 1.79 s
# ✓ Done.
# >> Dropping player name and was home columns ...
# CPU times: user 6.5 ms, sys: 3.1 ms, total: 9.6 ms
# Wall time: 9.07 ms
# >> Done.
# >> Dropping id columns ...
# CPU times: user 2.88 ms, sys: 1 ms, total: 3.88 ms
# Wall time: 3.85 ms
# ✓ Done.
# >> Augmenting player data for each gameweek ...
# --------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-01014ce96e04> in <module>
#     125                     df_.ix[index, "{}_pgw".format(target)] = 0
#     126                 else:
# --> 127                     df_.ix[index, "{}_pgw".format(target)] = df_.iloc[index-1][target]
#     128         new_df = new_df.append(df_)
#     129         later = time.time();
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     467
#     468             if isinstance(value, ABCSeries):
# --> 469                 value = self._align_series(indexer, value)
#     470
#     471             info_idx = indexer[info_axis]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#     781             return ser.reindex(ax)._values
#     782
# --> 783         raise ValueError('Incompatible indexer with Series')
#     784
#     785     def _align_frame(self, indexer, df):
#
# ValueError: Incompatible indexer with Series
