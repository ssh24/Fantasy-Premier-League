# %% [markdown]
# ### Combine all season by season prepared data (Step 10)
# #### Author: S. Sakib Hasan

# %%
import os
import pandas as pd
import numpy as np
import re

# %%
os.chdir(os.path.join(os.getcwd(), "..", "..", "data"));

# %%
os.getcwd()
# Out:
# '/Users/sakib@ibm.com/workspace/other/projects/Fantasy-Premier-League/dev/data'

# %%
df16 = pd.read_csv("2016-prepared-data.csv");
df17 = pd.read_csv("2017-prepared-data.csv");
df18 = pd.read_csv("2018-prepared-data.csv");
df19 = pd.read_csv("2019-prepared-data.csv");

# %%
df_merge = pd.concat([df16, df17, df18, df19])

# %%
df_merge.sort_values(["season", "GW"], inplace=True);

# %%
## only for duplicated player ids. this should be removed if the data preparation script is run with old season
df_merge.loc[(df_merge["player_id"] == 744), 'player_id'] = 201;
df_merge.loc[(df_merge["player_id"] == 948), 'player_id'] = 176;

# %%
df_merge[df_merge["player_id"] == 176]
# Out:
#        season  GW  at_home  player_id  opponent_id  champion_ls  top5_ls  \
# 6076     2016   1        0        176            2            0        0
# 6077     2016   2        1        176           13            0        0
# 6078     2016   3        0        176            7            0        0
# 6079     2016   4        1        176           10            0        1
# 6080     2016   5        0        176           18            0        0
# 6081     2016   6        1        176            8            1        1
# 6082     2016   7        1        176           14            0        0
# 6083     2016   8        0        176            9            0        0
# 6084     2016   9        0        176            4            0        0
# 6085     2016  10        1        176            3            0        0
# 6086     2016  11        0        176           16            0        0
# 6087     2016  12        1        176            1            0        1
# ...

# %%
df_merge.to_csv("combined-season-data.csv", index=False)
