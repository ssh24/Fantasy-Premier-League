# %% [markdown]
# ### Season by season data preparation (Step 7)
# #### Author: S. Sakib Hasan

# %%
import os
import pandas as pd
import numpy as np
import time

# %%
current_dir = os.getcwd()

# %%
os.chdir(os.path.join(os.getcwd(), "..", "..", "..", "dev", "data"));

# %%
team_id_df = pd.read_csv("team_id_map.csv");

# %%
player_id_df = pd.read_csv("player_id_map.csv");

# %%
os.chdir(current_dir);

# %%
seasons = ["2017-18"]

# %%
teams_in_season = {
    2016: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "West Bromwich Albion", "Southampton",
            "Leicester City", "Sunderland", "Hull City", "Swansea City", "Stoke City",
            "Middlesbrough", "West Ham United", "Burnley"],
        "champion_ls": "Leicester City",
        "top5_ls": ["Leicester City", "Arsenal", "Tottenham Hotspur", "Manchester City", "Manchester United"],
        "bottom5_ls": ["Watford", "West Bromwich Albion", "Crystal Palace", "Bournemouth", "Sunderland"],
        "promoted_ts": ["Middlesbrough", "Hull City", "Burnley"]
    },
    2017: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "West Bromwich Albion", "Southampton",
            "Leicester City", "Newcastle United", "Brighton and Hove Albion", "Swansea City", "Stoke City",
            "Huddersfield Town", "West Ham United", "Burnley"],
        "champion_ls": "Chelsea",
        "top5_ls": ["Chelsea", "Tottenham Hotspur", "Manchester City", "Liverpool", "Arsenal"],
        "bottom5_ls": ["Stoke City", "Crystal Palace", "Swansea City", "Burnley", "Watford"],
        "promoted_ts": ["Newcastle United", "Brighton and Hove Albion", "Huddersfield Town"]
    },
    2018: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "Wolverhampton Wanderers", "Southampton",
            "Leicester City", "Newcastle United", "Brighton and Hove Albion", "Cardiff City", "Fulham",
            "Huddersfield Town", "West Ham United", "Burnley"],
        "champion_ls": "Manchester City",
        "top5_ls": ["Manchester City", "Manchester United", "Tottenham Hotspur", "Liverpool", "Chelsea"],
        "bottom5_ls": ["West Ham United", "Watford", "Brighton and Hove Albion", "Huddersfield Town", "Southampton"],
        "promoted_ts": ["Wolverhampton Wanderers", "Cardiff City", "Fulham"]
    },
    2019: {
        "teams": ["Arsenal", "Liverpool", "Chelsea", "Bournemouth", "Crystal Palace", "Manchester City", "Watford",
            "Manchester United", "Tottenham Hotspur", "Everton", "Wolverhampton Wanderers", "Southampton",
            "Leicester City", "Newcastle United", "Brighton and Hove Albion", "Norwich City", "Aston Villa",
            "Sheffield United", "West Ham United", "Burnley"],
        "champion_ls": "Manchester City",
        "top5_ls": ["Manchester City", "Liverpool", "Chelsea", "Tottenham Hotspur", "Arsenal"],
        "bottom5_ls": ["Newcastle United", "Bournemouth", "Burnley", "Southampton", "Brighton and Hove Albion"],
        "promoted_ts": ["Norwich City", "Aston Villa", "Sheffield United"]
    }
}

# %%
# -1 means L
# 0 means D
# 1 means W
def getResult(row):
    if (row["team_h_score"] == row["team_a_score"]):
        return 0;
    elif (row["at_home"] == 1 and row["team_h_score"] < row["team_a_score"]):
        return -1;
    elif (row["at_home"] == 1 and row["team_h_score"] > row["team_a_score"]):
        return 1;
    elif (row["at_home"] == 0 and row["team_h_score"] < row["team_a_score"]):
        return 1;
    elif (row["at_home"] == 0 and row["team_h_score"] > row["team_a_score"]):
        return -1;

# %%
# main columns
cols = ["season", "GW", "at_home", "player_id", "opponent_id", "champion_ls", "top5_ls", "bottom5_ls", "promoted_ts",
        "influence", "creativity", "threat", "ict_index"];

# %%
# to remove columns after data augmented
to_remove_cols = ["minutes", "goals_scored", "goals_conceded", "assists", "clean_sheets", "own_goals", "yellow_cards", "red_cards", "penalties_saved", "penalties_missed",
       "saves", "bonus", "bps", "result"];

# %%
# reset column orders
reset_cols = ["season", "GW", "at_home", "player_id", "opponent_id", "champion_ls", "top5_ls", "bottom5_ls", 
              "promoted_ts", 'assists', 'assists_pgw', 'bonus', 'bonus_pgw', 'bps',
       'bps_pgw', 'clean_sheets', 'clean_sheets_pgw',
        'creativity', 'creativity_pgw', 'goals_conceded',
       'goals_conceded_pgw', 'goals_scored', 'goals_scored_pgw', 'ict_index',
       'ict_index_pgw', 'influence', 'influence_pgw', 'minutes', 'minutes_pgw',
       'own_goals', 'own_goals_pgw', 'penalties_missed', 'penalties_missed_pgw',
       'penalties_saved', 'penalties_saved_pgw', 'red_cards', 'red_cards_pgw', 'result', 'result_pgw', 'saves',
       'saves_pgw', 'threat',
       'threat_pgw','yellow_cards', 'yellow_cards_pgw', 'total_points_pgw', 'total_points']

# %%
# columns to fix - change the type of it to be int
cols_to_fix = ["GW", "at_home", "player_id", "opponent_id", "champion_ls", "top5_ls", "bottom5_ls", 
               "promoted_ts", "total_points"]

# %%
for season in seasons:
    print("Preparing data for season: {}".format(season));
    print('*' * 100);
    
    # set the target season as an int version: 2016-17 -> 2016
    target_season = int("".join(season.split("-")[:-1]));
    
    # get the list of teams in that season and sort them
    teams = teams_in_season[target_season]["teams"];
    teams.sort();
    
    # get the champions, top5, bottom5 and promoted teams for that season
    champion_ls = teams_in_season[target_season]["champion_ls"];
    top5_ls = teams_in_season[target_season]["top5_ls"];
    bottom5_ls = teams_in_season[target_season]["bottom5_ls"];
    promoted_ts = teams_in_season[target_season]["promoted_ts"];
    
    # change to the season data directory
    os.chdir(os.path.join(os.getcwd(), "..", "..", "..", "data", season, "gws"));
    
    # read the merged dataframe
    df = pd.read_csv("merged_gw_data.csv", index_col=False);
    
    # change to the data directory in the dev folder
    os.chdir(current_dir);
    os.chdir(os.path.join(os.getcwd(), "..", "..", "..", "dev", "data"));
    
    # set the season
    df["season"] = target_season;
    
    # set team from the list of teams that season
    print(">> Setting opponent team names ...");
    # %time df["team"] = df["opponent_team"].apply(lambda team: teams[team-1]);
    print("✓ Done.");
    
    # encode the teams into id
    print(">> Encoding opponent team names into team ids ...");
    # %time df["opponent_id"] = df["team"].apply(lambda team: team_id_df[team_id_df["team_name"] == team]["team_id"].iloc[0]);
    print("✓ Done.");
    
    # set column for is champions last season
    print(">> Creating column for champions last season ...");
    # %time df["champion_ls"] = df["team"].apply(lambda team: 1 if team == champion_ls else 0);
    print("✓ Done.");
    
    # set column for top 5 last season
    print(">> Creating column for top 5 last season ...");
    # %time df["top5_ls"] = df["team"].apply(lambda team: 1 if team in top5_ls else 0);
    print("✓ Done.");
    
    # set column for bottom 5 last season
    print(">> Creating column for bottom 5 last season ...");
    # %time df["bottom5_ls"] = df["team"].apply(lambda team: 1 if team in bottom5_ls else 0);
    print("✓ Done.");
    
    # set column for promoted teams this season
    print(">> Creating column for promoted teams this season ...");
    # %time df["promoted_ts"] = df["team"].apply(lambda team: 1 if team in promoted_ts else 0);
    print("✓ Done.");
    
    # drop the opponent team and team columns
    print(">> Dropping team and opponent_team columns ...");
    # %time df.drop(["team", "opponent_team"], axis=1, inplace=True);
    print("✓ Done.");
    
    # encode the players into id
    print(">> Encoding player names into player ids ...");
    # %time df["player_id"] = df["lower_name"].apply(lambda player: player_id_df[player_id_df["lower_name"] == player]["player_id"].iloc[0]);
    print("✓ Done.");
    
    # encode was_home into labels
    print(">> Encoding at home into boolean labels ...");
    # %time df["at_home"] = df["was_home"].apply(lambda at_home: 0 if not at_home else 1);
    print("✓ Done.");
    
    # encode the result into -1, 0, 1
    print(">> Creating a column for game result ...");
    # %time df["result"] = df.apply(lambda row: getResult(row), axis=1);
    print("✓ Done.");
    
    # drop the player name and was home columns
    print(">> Dropping player name and was home columns ...");
    # %time df.drop(["name", "lower_name", "was_home"], axis=1, inplace=True);
    print(">> Done.");
    
    # drop the id column
    if 'id' in df.columns:
        print(">> Dropping id columns ...");
        # %time df.drop(["id"], axis=1, inplace=True);
        print("✓ Done.");
        
    # set the target column
    target_col = ["total_points"];
    
    # set columns to be all the columns
    cols = cols + to_remove_cols + target_col;
    
    # create a subset dataframe with the new columns
    current_season = df[cols];
    
    # sort the subset dataframe
    current_season.sort_values(["GW"], inplace=True);
    current_season.reset_index(inplace=True, drop=True);
    
    # create target previous gameweek columns
    target_pgw = ["total_points", "ict_index", "influence", "creativity", "threat"];
    target_pgw = target_pgw + to_remove_cols;
    player_ids = np.unique(current_season["player_id"]);
    
    # create a new dataframe that will be augmented to
    new_df = pd.DataFrame(columns=list(current_season.columns));
    
    # loop through each unique player and augment the data
    print(">> Augmenting player data for each gameweek ...");
    print('-' * 50);
    for player_id in player_ids:
        now = time.time();
        df_ = current_season[current_season["player_id"] == player_id]
        df_.reset_index(inplace=True, drop=True)
        for index in range(len(df_)):
            instance = df_.iloc[index]
            gw = instance["GW"];
            for target in target_pgw:
                if (gw == 1 or index == 0):
                    df_.ix[index, "{}_pgw".format(target)] = 0
                else:
                    df_.ix[index, "{}_pgw".format(target)] = df_.iloc[index-1][target]
        new_df = new_df.append(df_)
        later = time.time();
        difference = int(later - now);
        print("Completed player id {} --- Time taken: {}s".format(player_id, difference));
    print("✓ Done.");
    print('-' * 50);
    
    # fix the indices
    new_df.reset_index(inplace=True, drop=True);
    
    # subset the reset columns
    new_df = new_df[reset_cols];
    
    # fix the reset columns
    for col in cols_to_fix:
        new_df[col] = new_df[col].astype(int)
    
    # save the dataframe
    filename = "{}-prepared-data.csv".format(target_season);
    new_df.to_csv(filename, index=False);
    
    print("Done preparing data for {}. File saved at: {}".format(season, os.path.join(os.getcwd(), filename)));
    print('*' * 100);
    print("\n");
    
    # switch back to the scripts directory
    os.chdir(current_dir);
# Out:
# Preparing data for season: 2017-18
# ****************************************************************************************************
# >> Setting opponent team names ...
# CPU times: user 5.08 ms, sys: 85 µs, total: 5.17 ms
# Wall time: 5.12 ms
# ✓ Done.
# >> Encoding opponent team names into team ids ...
# CPU times: user 13.2 s, sys: 187 ms, total: 13.4 s
# Wall time: 13.5 s
# ✓ Done.
# >> Creating column for champions last season ...
# CPU times: user 10.8 ms, sys: 491 µs, total: 11.3 ms
# Wall time: 11.3 ms
# ✓ Done.
# >> Creating column for top 5 last season ...
# CPU times: user 13.3 ms, sys: 276 µs, total: 13.6 ms
# Wall time: 13.5 ms
# ✓ Done.
# >> Creating column for bottom 5 last season ...
# CPU times: user 13.4 ms, sys: 408 µs, total: 13.8 ms
# Wall time: 14 ms
# ✓ Done.
# >> Creating column for promoted teams this season ...
# CPU times: user 11.9 ms, sys: 315 µs, total: 12.2 ms
# Wall time: 12.3 ms
# ✓ Done.
# >> Dropping team and opponent_team columns ...
# CPU times: user 17.7 ms, sys: 12.7 ms, total: 30.4 ms
# Wall time: 76.2 ms
# ✓ Done.
# >> Encoding player names into player ids ...
# CPU times: user 14.1 s, sys: 93.5 ms, total: 14.2 s
# Wall time: 14.3 s
# ✓ Done.
# >> Encoding at home into boolean labels ...
# CPU times: user 6.32 ms, sys: 43 µs, total: 6.36 ms
# Wall time: 6.31 ms
# ✓ Done.
# >> Creating a column for game result ...
# CPU times: user 1.12 s, sys: 18.9 ms, total: 1.14 s
# Wall time: 1.15 s
# ✓ Done.
# >> Dropping player name and was home columns ...
# CPU times: user 6.36 ms, sys: 2.75 ms, total: 9.12 ms
# Wall time: 8.57 ms
# >> Done.
# >> Dropping id columns ...
# CPU times: user 2.54 ms, sys: 1.07 ms, total: 3.61 ms
# Wall time: 3.58 ms
# ✓ Done.
# >> Augmenting player data for each gameweek ...
# --------------------------------------------------
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:125: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:127: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:6701: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Completed player id 1.0 --- Time taken: 15s
# Completed player id 2.0 --- Time taken: 16s
# Completed player id 3.0 --- Time taken: 14s
# Completed player id 4.0 --- Time taken: 16s
# Completed player id 5.0 --- Time taken: 8s
# Completed player id 6.0 --- Time taken: 15s
# Completed player id 10.0 --- Time taken: 14s
# Completed player id 12.0 --- Time taken: 15s
# Completed player id 15.0 --- Time taken: 15s
# Completed player id 18.0 --- Time taken: 16s
# Completed player id 21.0 --- Time taken: 16s
# Completed player id 22.0 --- Time taken: 16s
# Completed player id 24.0 --- Time taken: 15s
# Completed player id 25.0 --- Time taken: 5s
# Completed player id 26.0 --- Time taken: 14s
# Completed player id 28.0 --- Time taken: 16s
# Completed player id 30.0 --- Time taken: 15s
# Completed player id 33.0 --- Time taken: 15s
# Completed player id 34.0 --- Time taken: 15s
# Completed player id 35.0 --- Time taken: 14s
# Completed player id 36.0 --- Time taken: 2341s
# Completed player id 38.0 --- Time taken: 7s
# Completed player id 40.0 --- Time taken: 399s
# Completed player id 41.0 --- Time taken: 15s
# Completed player id 43.0 --- Time taken: 19s
# Completed player id 46.0 --- Time taken: 15s
# Completed player id 47.0 --- Time taken: 17s
# Completed player id 49.0 --- Time taken: 18s
# Completed player id 51.0 --- Time taken: 16s
# Completed player id 52.0 --- Time taken: 15s
# Completed player id 53.0 --- Time taken: 15s
# Completed player id 54.0 --- Time taken: 16s
# Completed player id 55.0 --- Time taken: 14s
# Completed player id 56.0 --- Time taken: 17s
# Completed player id 58.0 --- Time taken: 17s
# Completed player id 59.0 --- Time taken: 16s
# Completed player id 61.0 --- Time taken: 16s
# Completed player id 63.0 --- Time taken: 16s
# Completed player id 65.0 --- Time taken: 14s
# Completed player id 66.0 --- Time taken: 15s
# Completed player id 67.0 --- Time taken: 15s
# Completed player id 68.0 --- Time taken: 15s
# Completed player id 69.0 --- Time taken: 16s
# Completed player id 70.0 --- Time taken: 15s
# Completed player id 71.0 --- Time taken: 15s
# Completed player id 72.0 --- Time taken: 15s
# Completed player id 73.0 --- Time taken: 16s
# Completed player id 77.0 --- Time taken: 16s
# Completed player id 78.0 --- Time taken: 15s
# Completed player id 81.0 --- Time taken: 15s
# Completed player id 82.0 --- Time taken: 16s
# Completed player id 84.0 --- Time taken: 16s
# Completed player id 86.0 --- Time taken: 16s
# Completed player id 87.0 --- Time taken: 15s
# Completed player id 88.0 --- Time taken: 15s
# Completed player id 90.0 --- Time taken: 15s
# Completed player id 91.0 --- Time taken: 16s
# Completed player id 95.0 --- Time taken: 16s
# Completed player id 99.0 --- Time taken: 16s
# Completed player id 100.0 --- Time taken: 16s
# Completed player id 105.0 --- Time taken: 15s
# Completed player id 108.0 --- Time taken: 16s
# Completed player id 109.0 --- Time taken: 15s
# Completed player id 112.0 --- Time taken: 15s
# Completed player id 113.0 --- Time taken: 16s
# Completed player id 114.0 --- Time taken: 6s
# Completed player id 116.0 --- Time taken: 15s
# Completed player id 117.0 --- Time taken: 16s
# Completed player id 118.0 --- Time taken: 14s
# Completed player id 119.0 --- Time taken: 15s
# Completed player id 121.0 --- Time taken: 16s
# Completed player id 122.0 --- Time taken: 16s
# Completed player id 124.0 --- Time taken: 16s
# Completed player id 125.0 --- Time taken: 15s
# Completed player id 126.0 --- Time taken: 15s
# Completed player id 127.0 --- Time taken: 15s
# Completed player id 128.0 --- Time taken: 15s
# Completed player id 130.0 --- Time taken: 15s
# Completed player id 131.0 --- Time taken: 15s
# Completed player id 132.0 --- Time taken: 15s
# Completed player id 135.0 --- Time taken: 6s
# Completed player id 136.0 --- Time taken: 15s
# Completed player id 137.0 --- Time taken: 15s
# Completed player id 138.0 --- Time taken: 16s
# Completed player id 139.0 --- Time taken: 16s
# Completed player id 143.0 --- Time taken: 16s
# Completed player id 145.0 --- Time taken: 16s
# Completed player id 146.0 --- Time taken: 16s
# Completed player id 148.0 --- Time taken: 16s
# Completed player id 149.0 --- Time taken: 15s
# Completed player id 150.0 --- Time taken: 15s
# Completed player id 151.0 --- Time taken: 15s
# Completed player id 153.0 --- Time taken: 16s
# Completed player id 156.0 --- Time taken: 16s
# Completed player id 160.0 --- Time taken: 16s
# Completed player id 161.0 --- Time taken: 15s
# Completed player id 162.0 --- Time taken: 16s
# Completed player id 163.0 --- Time taken: 15s
# Completed player id 164.0 --- Time taken: 16s
# Completed player id 165.0 --- Time taken: 16s
# Completed player id 166.0 --- Time taken: 15s
# Completed player id 168.0 --- Time taken: 15s
# Completed player id 170.0 --- Time taken: 15s
# Completed player id 174.0 --- Time taken: 16s
# Completed player id 175.0 --- Time taken: 15s
# Completed player id 176.0 --- Time taken: 15s
# Completed player id 177.0 --- Time taken: 15s
# Completed player id 178.0 --- Time taken: 15s
# Completed player id 179.0 --- Time taken: 15s
# Completed player id 180.0 --- Time taken: 15s
# Completed player id 181.0 --- Time taken: 16s
# Completed player id 183.0 --- Time taken: 16s
# Completed player id 184.0 --- Time taken: 6s
# Completed player id 185.0 --- Time taken: 16s
# Completed player id 191.0 --- Time taken: 17s
# Completed player id 192.0 --- Time taken: 12s
# Completed player id 193.0 --- Time taken: 17s
# Completed player id 194.0 --- Time taken: 16s
# Completed player id 198.0 --- Time taken: 17s
# Completed player id 199.0 --- Time taken: 17s
# Completed player id 200.0 --- Time taken: 16s
# Completed player id 201.0 --- Time taken: 16s
# Completed player id 202.0 --- Time taken: 17s
# Completed player id 203.0 --- Time taken: 17s
# Completed player id 206.0 --- Time taken: 9s
# Completed player id 208.0 --- Time taken: 17s
# Completed player id 209.0 --- Time taken: 17s
# Completed player id 210.0 --- Time taken: 17s
# Completed player id 211.0 --- Time taken: 17s
# Completed player id 212.0 --- Time taken: 16s
# Completed player id 213.0 --- Time taken: 16s
# Completed player id 215.0 --- Time taken: 16s
# Completed player id 219.0 --- Time taken: 16s
# Completed player id 222.0 --- Time taken: 16s
# Completed player id 223.0 --- Time taken: 17s
# Completed player id 224.0 --- Time taken: 17s
# Completed player id 225.0 --- Time taken: 17s
# Completed player id 229.0 --- Time taken: 16s
# Completed player id 231.0 --- Time taken: 16s
# Completed player id 232.0 --- Time taken: 10s
# Completed player id 233.0 --- Time taken: 16s
# Completed player id 234.0 --- Time taken: 16s
# Completed player id 235.0 --- Time taken: 16s
# Completed player id 236.0 --- Time taken: 16s
# Completed player id 237.0 --- Time taken: 16s
# Completed player id 240.0 --- Time taken: 16s
# Completed player id 244.0 --- Time taken: 16s
# Completed player id 245.0 --- Time taken: 16s
# Completed player id 246.0 --- Time taken: 6s
# Completed player id 248.0 --- Time taken: 16s
# Completed player id 250.0 --- Time taken: 16s
# Completed player id 251.0 --- Time taken: 16s
# Completed player id 252.0 --- Time taken: 16s
# Completed player id 253.0 --- Time taken: 16s
# Completed player id 258.0 --- Time taken: 16s
# Completed player id 261.0 --- Time taken: 16s
# Completed player id 263.0 --- Time taken: 16s
# Completed player id 264.0 --- Time taken: 16s
# Completed player id 266.0 --- Time taken: 16s
# Completed player id 268.0 --- Time taken: 16s
# Completed player id 269.0 --- Time taken: 16s
# Completed player id 270.0 --- Time taken: 16s
# Completed player id 271.0 --- Time taken: 16s
# Completed player id 273.0 --- Time taken: 16s
# Completed player id 275.0 --- Time taken: 16s
# Completed player id 276.0 --- Time taken: 16s
# Completed player id 277.0 --- Time taken: 16s
# Completed player id 279.0 --- Time taken: 15s
# Completed player id 280.0 --- Time taken: 15s
# Completed player id 281.0 --- Time taken: 15s
# Completed player id 282.0 --- Time taken: 15s
# Completed player id 283.0 --- Time taken: 16s
# Completed player id 286.0 --- Time taken: 15s
# Completed player id 287.0 --- Time taken: 15s
# Completed player id 289.0 --- Time taken: 16s
# Completed player id 290.0 --- Time taken: 11s
# Completed player id 292.0 --- Time taken: 15s
# Completed player id 294.0 --- Time taken: 15s
# Completed player id 295.0 --- Time taken: 15s
# Completed player id 296.0 --- Time taken: 15s
# Completed player id 297.0 --- Time taken: 16s
# Completed player id 298.0 --- Time taken: 16s
# Completed player id 299.0 --- Time taken: 16s
# Completed player id 300.0 --- Time taken: 15s
# Completed player id 301.0 --- Time taken: 16s
# Completed player id 304.0 --- Time taken: 16s
# Completed player id 306.0 --- Time taken: 16s
# Completed player id 309.0 --- Time taken: 16s
# Completed player id 310.0 --- Time taken: 16s
# Completed player id 311.0 --- Time taken: 16s
# Completed player id 312.0 --- Time taken: 16s
# Completed player id 313.0 --- Time taken: 16s
# Completed player id 315.0 --- Time taken: 16s
# Completed player id 316.0 --- Time taken: 15s
# Completed player id 318.0 --- Time taken: 15s
# Completed player id 319.0 --- Time taken: 15s
# Completed player id 320.0 --- Time taken: 16s
# Completed player id 322.0 --- Time taken: 16s
# Completed player id 323.0 --- Time taken: 15s
# Completed player id 326.0 --- Time taken: 15s
# Completed player id 329.0 --- Time taken: 16s
# Completed player id 330.0 --- Time taken: 16s
# Completed player id 332.0 --- Time taken: 16s
# Completed player id 334.0 --- Time taken: 16s
# Completed player id 337.0 --- Time taken: 16s
# Completed player id 340.0 --- Time taken: 16s
# Completed player id 344.0 --- Time taken: 16s
# Completed player id 345.0 --- Time taken: 17s
# Completed player id 347.0 --- Time taken: 16s
# Completed player id 348.0 --- Time taken: 16s
# Completed player id 349.0 --- Time taken: 16s
# Completed player id 350.0 --- Time taken: 17s
# Completed player id 351.0 --- Time taken: 16s
# Completed player id 354.0 --- Time taken: 16s
# Completed player id 355.0 --- Time taken: 13s
# Completed player id 356.0 --- Time taken: 16s
# Completed player id 358.0 --- Time taken: 15s
# Completed player id 359.0 --- Time taken: 15s
# Completed player id 360.0 --- Time taken: 16s
# Completed player id 362.0 --- Time taken: 7s
# Completed player id 365.0 --- Time taken: 16s
# Completed player id 367.0 --- Time taken: 16s
# Completed player id 369.0 --- Time taken: 15s
# Completed player id 370.0 --- Time taken: 16s
# Completed player id 373.0 --- Time taken: 16s
# Completed player id 375.0 --- Time taken: 16s
# Completed player id 376.0 --- Time taken: 12s
# Completed player id 378.0 --- Time taken: 16s
# Completed player id 379.0 --- Time taken: 16s
# Completed player id 381.0 --- Time taken: 16s
# Completed player id 382.0 --- Time taken: 16s
# Completed player id 383.0 --- Time taken: 16s
# Completed player id 384.0 --- Time taken: 15s
# Completed player id 385.0 --- Time taken: 16s
# Completed player id 386.0 --- Time taken: 16s
# Completed player id 387.0 --- Time taken: 16s
# Completed player id 389.0 --- Time taken: 16s
# Completed player id 390.0 --- Time taken: 15s
# Completed player id 392.0 --- Time taken: 15s
# Completed player id 393.0 --- Time taken: 15s
# Completed player id 394.0 --- Time taken: 16s
# Completed player id 395.0 --- Time taken: 16s
# Completed player id 396.0 --- Time taken: 16s
# Completed player id 398.0 --- Time taken: 16s
# Completed player id 401.0 --- Time taken: 16s
# Completed player id 402.0 --- Time taken: 16s
# Completed player id 403.0 --- Time taken: 15s
# Completed player id 404.0 --- Time taken: 16s
# Completed player id 405.0 --- Time taken: 15s
# Completed player id 406.0 --- Time taken: 15s
# Completed player id 407.0 --- Time taken: 17s
# Completed player id 408.0 --- Time taken: 16s
# Completed player id 411.0 --- Time taken: 17s
# Completed player id 413.0 --- Time taken: 17s
# Completed player id 414.0 --- Time taken: 17s
# Completed player id 416.0 --- Time taken: 17s
# Completed player id 418.0 --- Time taken: 16s
# Completed player id 421.0 --- Time taken: 16s
# Completed player id 423.0 --- Time taken: 16s
# Completed player id 425.0 --- Time taken: 16s
# Completed player id 428.0 --- Time taken: 16s
# Completed player id 429.0 --- Time taken: 15s
# Completed player id 430.0 --- Time taken: 15s
# Completed player id 431.0 --- Time taken: 15s
# Completed player id 432.0 --- Time taken: 15s
# Completed player id 433.0 --- Time taken: 16s
# Completed player id 434.0 --- Time taken: 16s
# Completed player id 435.0 --- Time taken: 16s
# Completed player id 439.0 --- Time taken: 15s
# Completed player id 440.0 --- Time taken: 16s
# Completed player id 441.0 --- Time taken: 4s
# Completed player id 442.0 --- Time taken: 16s
# Completed player id 445.0 --- Time taken: 16s
# Completed player id 446.0 --- Time taken: 17s
# Completed player id 447.0 --- Time taken: 16s
# Completed player id 449.0 --- Time taken: 17s
# Completed player id 451.0 --- Time taken: 17s
# Completed player id 452.0 --- Time taken: 17s
# Completed player id 455.0 --- Time taken: 16s
# Completed player id 458.0 --- Time taken: 12s
# Completed player id 460.0 --- Time taken: 13s
# Completed player id 462.0 --- Time taken: 17s
# Completed player id 463.0 --- Time taken: 16s
# Completed player id 464.0 --- Time taken: 17s
# Completed player id 466.0 --- Time taken: 16s
# Completed player id 467.0 --- Time taken: 16s
# Completed player id 470.0 --- Time taken: 17s
# Completed player id 471.0 --- Time taken: 17s
# Completed player id 472.0 --- Time taken: 17s
# Completed player id 474.0 --- Time taken: 17s
# Completed player id 475.0 --- Time taken: 17s
# Completed player id 477.0 --- Time taken: 9s
# Completed player id 478.0 --- Time taken: 18s
# Completed player id 483.0 --- Time taken: 17s
# Completed player id 484.0 --- Time taken: 15s
# Completed player id 485.0 --- Time taken: 15s
# Completed player id 486.0 --- Time taken: 17s
# Completed player id 487.0 --- Time taken: 17s
# Completed player id 489.0 --- Time taken: 17s
# Completed player id 490.0 --- Time taken: 16s
# Completed player id 491.0 --- Time taken: 16s
# Completed player id 492.0 --- Time taken: 16s
# Completed player id 493.0 --- Time taken: 17s
# Completed player id 494.0 --- Time taken: 9s
# Completed player id 497.0 --- Time taken: 16s
# Completed player id 498.0 --- Time taken: 16s
# Completed player id 499.0 --- Time taken: 16s
# Completed player id 500.0 --- Time taken: 16s
# Completed player id 502.0 --- Time taken: 17s
# Completed player id 503.0 --- Time taken: 18s
# Completed player id 504.0 --- Time taken: 16s
# Completed player id 505.0 --- Time taken: 16s
# Completed player id 506.0 --- Time taken: 17s
# Completed player id 508.0 --- Time taken: 16s
# Completed player id 509.0 --- Time taken: 15s
# Completed player id 510.0 --- Time taken: 15s
# Completed player id 512.0 --- Time taken: 16s
# Completed player id 513.0 --- Time taken: 18s
# Completed player id 514.0 --- Time taken: 17s
# Completed player id 516.0 --- Time taken: 18s
# Completed player id 519.0 --- Time taken: 16s
# Completed player id 520.0 --- Time taken: 14s
# Completed player id 521.0 --- Time taken: 17s
# Completed player id 522.0 --- Time taken: 17s
# Completed player id 524.0 --- Time taken: 16s
# Completed player id 525.0 --- Time taken: 8s
# Completed player id 527.0 --- Time taken: 16s
# Completed player id 529.0 --- Time taken: 14s
# Completed player id 532.0 --- Time taken: 16s
# Completed player id 533.0 --- Time taken: 16s
# Completed player id 537.0 --- Time taken: 16s
# Completed player id 539.0 --- Time taken: 17s
# Completed player id 540.0 --- Time taken: 17s
# Completed player id 541.0 --- Time taken: 12s
# Completed player id 543.0 --- Time taken: 16s
# Completed player id 544.0 --- Time taken: 16s
# Completed player id 545.0 --- Time taken: 17s
# Completed player id 546.0 --- Time taken: 17s
# Completed player id 547.0 --- Time taken: 16s
# Completed player id 548.0 --- Time taken: 18s
# Completed player id 549.0 --- Time taken: 16s
# Completed player id 550.0 --- Time taken: 17s
# Completed player id 552.0 --- Time taken: 17s
# Completed player id 553.0 --- Time taken: 17s
# Completed player id 554.0 --- Time taken: 17s
# Completed player id 555.0 --- Time taken: 15s
# Completed player id 556.0 --- Time taken: 16s
# Completed player id 557.0 --- Time taken: 17s
# Completed player id 559.0 --- Time taken: 6s
# Completed player id 560.0 --- Time taken: 6s
# Completed player id 561.0 --- Time taken: 18s
# Completed player id 566.0 --- Time taken: 18s
# Completed player id 567.0 --- Time taken: 18s
# Completed player id 568.0 --- Time taken: 17s
# Completed player id 569.0 --- Time taken: 17s
# Completed player id 570.0 --- Time taken: 16s
# Completed player id 571.0 --- Time taken: 16s
# Completed player id 572.0 --- Time taken: 17s
# Completed player id 573.0 --- Time taken: 15s
# Completed player id 574.0 --- Time taken: 15s
# Completed player id 576.0 --- Time taken: 16s
# Completed player id 578.0 --- Time taken: 15s
# Completed player id 581.0 --- Time taken: 17s
# Completed player id 582.0 --- Time taken: 17s
# Completed player id 584.0 --- Time taken: 17s
# Completed player id 585.0 --- Time taken: 16s
# Completed player id 586.0 --- Time taken: 16s
# Completed player id 587.0 --- Time taken: 16s
# Completed player id 588.0 --- Time taken: 17s
# Completed player id 589.0 --- Time taken: 15s
# Completed player id 590.0 --- Time taken: 17s
# Completed player id 591.0 --- Time taken: 17s
# Completed player id 593.0 --- Time taken: 17s
# Completed player id 596.0 --- Time taken: 17s
# Completed player id 597.0 --- Time taken: 16s
# Completed player id 598.0 --- Time taken: 17s
# Completed player id 599.0 --- Time taken: 17s
# Completed player id 600.0 --- Time taken: 17s
# Completed player id 602.0 --- Time taken: 16s
# Completed player id 604.0 --- Time taken: 17s
# Completed player id 605.0 --- Time taken: 16s
# Completed player id 606.0 --- Time taken: 16s
# Completed player id 610.0 --- Time taken: 15s
# Completed player id 611.0 --- Time taken: 15s
# Completed player id 612.0 --- Time taken: 15s
# Completed player id 613.0 --- Time taken: 15s
# Completed player id 615.0 --- Time taken: 16s
# Completed player id 616.0 --- Time taken: 16s
# Completed player id 617.0 --- Time taken: 16s
# Completed player id 618.0 --- Time taken: 7s
# Completed player id 619.0 --- Time taken: 16s
# Completed player id 620.0 --- Time taken: 16s
# Completed player id 621.0 --- Time taken: 16s
# Completed player id 623.0 --- Time taken: 16s
# Completed player id 624.0 --- Time taken: 16s
# Completed player id 625.0 --- Time taken: 16s
# Completed player id 628.0 --- Time taken: 16s
# Completed player id 629.0 --- Time taken: 16s
# Completed player id 630.0 --- Time taken: 17s
# Completed player id 634.0 --- Time taken: 15s
# Completed player id 636.0 --- Time taken: 16s
# Completed player id 637.0 --- Time taken: 14s
# Completed player id 639.0 --- Time taken: 15s
# Completed player id 640.0 --- Time taken: 16s
# Completed player id 642.0 --- Time taken: 16s
# Completed player id 643.0 --- Time taken: 17s
# Completed player id 644.0 --- Time taken: 16s
# Completed player id 645.0 --- Time taken: 15s
# Completed player id 648.0 --- Time taken: 14s
# Completed player id 649.0 --- Time taken: 16s
# Completed player id 651.0 --- Time taken: 16s
# Completed player id 652.0 --- Time taken: 15s
# Completed player id 654.0 --- Time taken: 16s
# Completed player id 655.0 --- Time taken: 16s
# Completed player id 657.0 --- Time taken: 17s
# Completed player id 658.0 --- Time taken: 16s
# Completed player id 659.0 --- Time taken: 16s
# Completed player id 663.0 --- Time taken: 16s
# Completed player id 664.0 --- Time taken: 17s
# Completed player id 665.0 --- Time taken: 17s
# Completed player id 666.0 --- Time taken: 16s
# Completed player id 667.0 --- Time taken: 16s
# Completed player id 668.0 --- Time taken: 15s
# Completed player id 669.0 --- Time taken: 16s
# Completed player id 671.0 --- Time taken: 16s
# Completed player id 672.0 --- Time taken: 15s
# Completed player id 673.0 --- Time taken: 16s
# Completed player id 674.0 --- Time taken: 15s
# Completed player id 675.0 --- Time taken: 16s
# Completed player id 677.0 --- Time taken: 15s
# Completed player id 678.0 --- Time taken: 15s
# Completed player id 679.0 --- Time taken: 15s
# Completed player id 681.0 --- Time taken: 15s
# Completed player id 684.0 --- Time taken: 15s
# Completed player id 685.0 --- Time taken: 14s
# Completed player id 686.0 --- Time taken: 13s
# Completed player id 687.0 --- Time taken: 7s
# Completed player id 688.0 --- Time taken: 15s
# Completed player id 689.0 --- Time taken: 14s
# Completed player id 690.0 --- Time taken: 16s
# Completed player id 691.0 --- Time taken: 5s
# Completed player id 692.0 --- Time taken: 16s
# Completed player id 693.0 --- Time taken: 12s
# Completed player id 694.0 --- Time taken: 6s
# Completed player id 695.0 --- Time taken: 13s
# Completed player id 696.0 --- Time taken: 16s
# Completed player id 697.0 --- Time taken: 15s
# Completed player id 698.0 --- Time taken: 15s
# Completed player id 699.0 --- Time taken: 10s
# Completed player id 700.0 --- Time taken: 14s
# Completed player id 701.0 --- Time taken: 5s
# Completed player id 702.0 --- Time taken: 14s
# Completed player id 703.0 --- Time taken: 9s
# Completed player id 704.0 --- Time taken: 11s
# Completed player id 705.0 --- Time taken: 15s
# Completed player id 706.0 --- Time taken: 14s
# Completed player id 707.0 --- Time taken: 15s
# Completed player id 708.0 --- Time taken: 15s
# Completed player id 709.0 --- Time taken: 15s
# Completed player id 710.0 --- Time taken: 15s
# Completed player id 711.0 --- Time taken: 8s
# Completed player id 712.0 --- Time taken: 7s
# Completed player id 713.0 --- Time taken: 16s
# Completed player id 714.0 --- Time taken: 15s
# Completed player id 715.0 --- Time taken: 16s
# Completed player id 716.0 --- Time taken: 16s
# Completed player id 717.0 --- Time taken: 15s
# Completed player id 718.0 --- Time taken: 15s
# Completed player id 719.0 --- Time taken: 16s
# Completed player id 720.0 --- Time taken: 14s
# Completed player id 721.0 --- Time taken: 14s
# Completed player id 722.0 --- Time taken: 15s
# Completed player id 723.0 --- Time taken: 7s
# Completed player id 724.0 --- Time taken: 2s
# Completed player id 725.0 --- Time taken: 2s
# Completed player id 726.0 --- Time taken: 14s
# Completed player id 727.0 --- Time taken: 8s
# Completed player id 728.0 --- Time taken: 14s
# Completed player id 729.0 --- Time taken: 14s
# Completed player id 730.0 --- Time taken: 15s
# Completed player id 731.0 --- Time taken: 15s
# Completed player id 732.0 --- Time taken: 14s
# Completed player id 733.0 --- Time taken: 14s
# Completed player id 734.0 --- Time taken: 16s
# Completed player id 735.0 --- Time taken: 15s
# Completed player id 736.0 --- Time taken: 15s
# Completed player id 737.0 --- Time taken: 4s
# Completed player id 738.0 --- Time taken: 13s
# Completed player id 739.0 --- Time taken: 5s
# Completed player id 740.0 --- Time taken: 6s
# Completed player id 741.0 --- Time taken: 16s
# Completed player id 742.0 --- Time taken: 0s
# Completed player id 743.0 --- Time taken: 16s
# Completed player id 745.0 --- Time taken: 12s
# Completed player id 746.0 --- Time taken: 15s
# Completed player id 747.0 --- Time taken: 5s
# Completed player id 748.0 --- Time taken: 5s
# Completed player id 749.0 --- Time taken: 14s
# Completed player id 750.0 --- Time taken: 9s
# Completed player id 751.0 --- Time taken: 11s
# Completed player id 752.0 --- Time taken: 13s
# Completed player id 753.0 --- Time taken: 15s
# Completed player id 754.0 --- Time taken: 14s
# Completed player id 755.0 --- Time taken: 14s
# Completed player id 756.0 --- Time taken: 6s
# Completed player id 757.0 --- Time taken: 15s
# Completed player id 758.0 --- Time taken: 14s
# Completed player id 759.0 --- Time taken: 15s
# Completed player id 760.0 --- Time taken: 7s
# Completed player id 761.0 --- Time taken: 15s
# Completed player id 762.0 --- Time taken: 3s
# Completed player id 763.0 --- Time taken: 15s
# Completed player id 764.0 --- Time taken: 14s
# Completed player id 765.0 --- Time taken: 6s
# Completed player id 766.0 --- Time taken: 10s
# Completed player id 767.0 --- Time taken: 14s
# Completed player id 768.0 --- Time taken: 13s
# Completed player id 769.0 --- Time taken: 2s
# Completed player id 770.0 --- Time taken: 15s
# Completed player id 771.0 --- Time taken: 16s
# Completed player id 772.0 --- Time taken: 15s
# Completed player id 773.0 --- Time taken: 15s
# Completed player id 774.0 --- Time taken: 16s
# Completed player id 775.0 --- Time taken: 11s
# Completed player id 776.0 --- Time taken: 15s
# Completed player id 777.0 --- Time taken: 16s
# Completed player id 778.0 --- Time taken: 16s
# Completed player id 779.0 --- Time taken: 2s
# Completed player id 780.0 --- Time taken: 15s
# Completed player id 781.0 --- Time taken: 16s
# Completed player id 782.0 --- Time taken: 6s
# Completed player id 783.0 --- Time taken: 16s
# Completed player id 784.0 --- Time taken: 16s
# Completed player id 785.0 --- Time taken: 13s
# Completed player id 786.0 --- Time taken: 14s
# Completed player id 787.0 --- Time taken: 14s
# Completed player id 788.0 --- Time taken: 15s
# Completed player id 789.0 --- Time taken: 14s
# Completed player id 790.0 --- Time taken: 15s
# Completed player id 791.0 --- Time taken: 11s
# Completed player id 792.0 --- Time taken: 14s
# Completed player id 793.0 --- Time taken: 15s
# Completed player id 794.0 --- Time taken: 15s
# Completed player id 795.0 --- Time taken: 16s
# Completed player id 796.0 --- Time taken: 16s
# Completed player id 797.0 --- Time taken: 5s
# Completed player id 798.0 --- Time taken: 2s
# Completed player id 799.0 --- Time taken: 4s
# Completed player id 800.0 --- Time taken: 3s
# Completed player id 801.0 --- Time taken: 14s
# Completed player id 802.0 --- Time taken: 5s
# Completed player id 803.0 --- Time taken: 6s
# Completed player id 804.0 --- Time taken: 14s
# Completed player id 805.0 --- Time taken: 5s
# Completed player id 806.0 --- Time taken: 16s
# Completed player id 807.0 --- Time taken: 16s
# Completed player id 808.0 --- Time taken: 2s
# Completed player id 809.0 --- Time taken: 7s
# Completed player id 810.0 --- Time taken: 6s
# Completed player id 811.0 --- Time taken: 16s
# Completed player id 812.0 --- Time taken: 5s
# Completed player id 813.0 --- Time taken: 15s
# Completed player id 814.0 --- Time taken: 6s
# Completed player id 815.0 --- Time taken: 15s
# Completed player id 816.0 --- Time taken: 3s
# Completed player id 817.0 --- Time taken: 14s
# Completed player id 818.0 --- Time taken: 0s
# Completed player id 819.0 --- Time taken: 13s
# Completed player id 820.0 --- Time taken: 14s
# Completed player id 821.0 --- Time taken: 15s
# Completed player id 822.0 --- Time taken: 5s
# Completed player id 823.0 --- Time taken: 4s
# Completed player id 824.0 --- Time taken: 4s
# Completed player id 825.0 --- Time taken: 15s
# Completed player id 826.0 --- Time taken: 15s
# Completed player id 827.0 --- Time taken: 14s
# Completed player id 828.0 --- Time taken: 15s
# Completed player id 829.0 --- Time taken: 5s
# Completed player id 830.0 --- Time taken: 14s
# Completed player id 831.0 --- Time taken: 15s
# Completed player id 832.0 --- Time taken: 14s
# Completed player id 833.0 --- Time taken: 15s
# Completed player id 834.0 --- Time taken: 7s
# Completed player id 835.0 --- Time taken: 16s
# Completed player id 836.0 --- Time taken: 15s
# Completed player id 837.0 --- Time taken: 9s
# Completed player id 838.0 --- Time taken: 16s
# Completed player id 839.0 --- Time taken: 6s
# Completed player id 840.0 --- Time taken: 16s
# Completed player id 841.0 --- Time taken: 14s
# Completed player id 842.0 --- Time taken: 6s
# Completed player id 843.0 --- Time taken: 15s
# Completed player id 844.0 --- Time taken: 9s
# Completed player id 845.0 --- Time taken: 10s
# Completed player id 846.0 --- Time taken: 15s
# Completed player id 847.0 --- Time taken: 13s
# Completed player id 848.0 --- Time taken: 4s
# Completed player id 849.0 --- Time taken: 14s
# Completed player id 850.0 --- Time taken: 15s
# Completed player id 851.0 --- Time taken: 13s
# Completed player id 852.0 --- Time taken: 5s
# Completed player id 853.0 --- Time taken: 14s
# Completed player id 854.0 --- Time taken: 5s
# Completed player id 855.0 --- Time taken: 14s
# Completed player id 856.0 --- Time taken: 14s
# Completed player id 857.0 --- Time taken: 14s
# Completed player id 858.0 --- Time taken: 5s
# Completed player id 859.0 --- Time taken: 2s
# Completed player id 860.0 --- Time taken: 14s
# Completed player id 861.0 --- Time taken: 9s
# Completed player id 862.0 --- Time taken: 15s
# Completed player id 863.0 --- Time taken: 13s
# Completed player id 864.0 --- Time taken: 14s
# Completed player id 865.0 --- Time taken: 15s
# Completed player id 866.0 --- Time taken: 13s
# Completed player id 867.0 --- Time taken: 15s
# Completed player id 868.0 --- Time taken: 16s
# Completed player id 869.0 --- Time taken: 16s
# Completed player id 870.0 --- Time taken: 1s
# Completed player id 871.0 --- Time taken: 15s
# Completed player id 872.0 --- Time taken: 15s
# Completed player id 873.0 --- Time taken: 16s
# Completed player id 874.0 --- Time taken: 15s
# Completed player id 875.0 --- Time taken: 16s
# Completed player id 876.0 --- Time taken: 15s
# Completed player id 877.0 --- Time taken: 16s
# Completed player id 878.0 --- Time taken: 15s
# Completed player id 879.0 --- Time taken: 14s
# Completed player id 880.0 --- Time taken: 16s
# Completed player id 881.0 --- Time taken: 16s
# Completed player id 882.0 --- Time taken: 16s
# Completed player id 883.0 --- Time taken: 14s
# Completed player id 884.0 --- Time taken: 7s
# Completed player id 885.0 --- Time taken: 16s
# Completed player id 886.0 --- Time taken: 14s
# Completed player id 887.0 --- Time taken: 16s
# Completed player id 888.0 --- Time taken: 15s
# Completed player id 889.0 --- Time taken: 15s
# Completed player id 890.0 --- Time taken: 4s
# Completed player id 891.0 --- Time taken: 4s
# Completed player id 892.0 --- Time taken: 15s
# Completed player id 893.0 --- Time taken: 15s
# Completed player id 894.0 --- Time taken: 14s
# Completed player id 895.0 --- Time taken: 13s
# Completed player id 896.0 --- Time taken: 15s
# Completed player id 897.0 --- Time taken: 16s
# Completed player id 898.0 --- Time taken: 16s
# ✓ Done.
# --------------------------------------------------
# Done preparing data for 2017-18. File saved at: /Users/sakib@ibm.com/workspace/other/projects/Fantasy-Premier-League/dev/data/2017-prepared-data.csv
# ****************************************************************************************************
